# %% [markdown]
# <a href="https://colab.research.google.com/github/RoxioMarks/sales-predictions/blob/main/Proyecto_1_Parte_2_(base)_predicciones_de_ventas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
filename ='/content/sales_predictions.csv'
df = pd.read_csv(filename)
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# ###Para la parte 2, la tarea es usar Pandas para empezar a limpiar y explorar los datos. Al ser científicos de datos, alrededor del 80% de nuestro tiempo se dedica a la preparación de datos, así que este es un paso muy importante.Sus datos ya deberían estar cargados en el cuaderno de la parte 1 del proyecto.Exploren los datos - ¿Qué necesitan para limpiar estos datos? ¡Límpienlos!

# %% [markdown]
# **1) ¿Cuántas filas y columnas?**

# %%
df.shape
# Out:
# (8523, 12)

# %% [markdown]
# **2) ¿Cuáles son los tipos de datos en cada variable?**

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %% [markdown]
# **3) ¿Hay duplicados? Si es el caso, eliminen algunos duplicados.**

# %%
# cant. de duplicados
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **4) Identifiquen los valores faltantes.**

# %%
#Los datos faltantes se definen como valores no disponibles que serían útiles o significativos para el análisis de los resultados.
#¿Cuántos valores faltantes hay en el conjunto de datos? ¿En qué columnas están?
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# **5) Decidan cómo abordar los valores faltantes y cómo hacerlo. (Esto requiere sus criterios, así que expliquen su elección).**

# %%
# Rellaneremos los valores faltantes en la columna Item_Weight con el valor correcto según el Item_Identifier, ya que si hay otros registros iguales pero que si tienen el valor de Item_Weight

df.loc[df.Item_Identifier == 'FDA15','Item_Weight']=9.3
df.loc[df.Item_Identifier == 'DRC01','Item_Weight']=5.92
df.loc[df.Item_Identifier == 'FDN15','Item_Weight']=17.5
df.loc[df.Item_Identifier == 'FDX07','Item_Weight']=19.2
df.loc[df.Item_Identifier == 'NCD19','Item_Weight']=8.93
df.loc[df.Item_Identifier == 'FDP36','Item_Weight']=10.395
df.loc[df.Item_Identifier == 'FDO10','Item_Weight']=13.65
df.loc[df.Item_Identifier == 'FDH17','Item_Weight']=16.2
df.loc[df.Item_Identifier == 'FDU28','Item_Weight']=19.2
df.loc[df.Item_Identifier == 'FDY07','Item_Weight']=11.8
df.loc[df.Item_Identifier == 'FDA03','Item_Weight']=18.5
df.loc[df.Item_Identifier == 'FDX32','Item_Weight']=15.1
df.loc[df.Item_Identifier == 'FDS46','Item_Weight']=17.6
df.loc[df.Item_Identifier == 'FDF32','Item_Weight']=16.35
df.loc[df.Item_Identifier == 'FDP49','Item_Weight']=9
df.loc[df.Item_Identifier == 'NCB42','Item_Weight']=11.8
df.loc[df.Item_Identifier == 'FDU02','Item_Weight']=13.35
df.loc[df.Item_Identifier == 'FDN22','Item_Weight']=18.85
df.loc[df.Item_Identifier == 'NCB30','Item_Weight']=14.6
df.loc[df.Item_Identifier == 'FDR28','Item_Weight']=13.85
df.loc[df.Item_Identifier == 'NCD06','Item_Weight']=13
df.loc[df.Item_Identifier == 'FDV10','Item_Weight']=7.645
df.loc[df.Item_Identifier == 'DRJ59','Item_Weight']=11.65
df.loc[df.Item_Identifier == 'FDE51','Item_Weight']=5.925
df.loc[df.Item_Identifier == 'FDV38','Item_Weight']=19.25
df.loc[df.Item_Identifier == 'NCS17','Item_Weight']=18.6
df.loc[df.Item_Identifier == 'FDP33','Item_Weight']=18.7
df.loc[df.Item_Identifier == 'FDO23','Item_Weight']=17.85
df.loc[df.Item_Identifier == 'DRH01','Item_Weight']=17.5
df.loc[df.Item_Identifier == 'NCX29','Item_Weight']=10
df.loc[df.Item_Identifier == 'DRZ11','Item_Weight']=8.85
df.loc[df.Item_Identifier == 'FDK43','Item_Weight']=9.8
df.loc[df.Item_Identifier == 'FDA46','Item_Weight']=13.6
df.loc[df.Item_Identifier == 'FDC02','Item_Weight']=21.35
df.loc[df.Item_Identifier == 'FDL50','Item_Weight']=12.15
df.loc[df.Item_Identifier == 'FDM39','Item_Weight']=6.42
df.loc[df.Item_Identifier == 'NCP05','Item_Weight']=19.6
df.loc[df.Item_Identifier == 'FDV49','Item_Weight']=10
df.loc[df.Item_Identifier == 'FDL12','Item_Weight']=15.85
df.loc[df.Item_Identifier == 'NCL17','Item_Weight']=7.39
df.loc[df.Item_Identifier == 'FDM40','Item_Weight']=10.195
df.loc[df.Item_Identifier == 'FDR13','Item_Weight']=9.895
df.loc[df.Item_Identifier == 'FDA43','Item_Weight']=10.895
df.loc[df.Item_Identifier == 'NCP18','Item_Weight']=12.15
df.loc[df.Item_Identifier == 'FDK21','Item_Weight']=7.905
df.loc[df.Item_Identifier == 'NCX54','Item_Weight']=9.195
df.loc[df.Item_Identifier == 'DRK35','Item_Weight']=8.365
df.loc[df.Item_Identifier == 'FDY21','Item_Weight']=15.1
df.loc[df.Item_Identifier == 'FDM20','Item_Weight']=10
df.loc[df.Item_Identifier == 'FDV27','Item_Weight']=7.97
df.loc[df.Item_Identifier == 'FDC46','Item_Weight']=17.7
df.loc[df.Item_Identifier == 'FDH19','Item_Weight']=19.35
df.loc[df.Item_Identifier == 'FDZ03','Item_Weight']=13.65
df.loc[df.Item_Identifier == 'DRH37','Item_Weight']=17.6
df.loc[df.Item_Identifier == 'NCI17','Item_Weight']=8.645
df.loc[df.Item_Identifier == 'FDJ58','Item_Weight']=15.6
df.loc[df.Item_Identifier == 'FDH35','Item_Weight']=18.25
df.loc[df.Item_Identifier == 'FDG02','Item_Weight']=7.855
df.loc[df.Item_Identifier == 'NCZ18','Item_Weight']=7.825
df.loc[df.Item_Identifier == 'FDC29','Item_Weight']=8.39
df.loc[df.Item_Identifier == 'FDQ10','Item_Weight']=12.85
df.loc[df.Item_Identifier == 'FDL04','Item_Weight']=19
df.loc[df.Item_Identifier == 'FDV25','Item_Weight']=5.905
df.loc[df.Item_Identifier == 'FDD58','Item_Weight']=7.76
df.loc[df.Item_Identifier == 'FDN04','Item_Weight']=11.8
df.loc[df.Item_Identifier == 'FDV45','Item_Weight']=16.75
df.loc[df.Item_Identifier == 'FDG20','Item_Weight']=15.5
df.loc[df.Item_Identifier == 'FDZ55','Item_Weight']=6.055
df.loc[df.Item_Identifier == 'FDN33','Item_Weight']=6.305
df.loc[df.Item_Identifier == 'FDN27','Item_Weight']=20.85
df.loc[df.Item_Identifier == 'FDW20','Item_Weight']=20.75
df.loc[df.Item_Identifier == 'DRG27','Item_Weight']=8.895
df.loc[df.Item_Identifier == 'DRI25','Item_Weight']=19.6
df.loc[df.Item_Identifier == 'FDA44','Item_Weight']=19.7
df.loc[df.Item_Identifier == 'NCR17','Item_Weight']=9.8
df.loc[df.Item_Identifier == 'FDF41','Item_Weight']=12.15
df.loc[df.Item_Identifier == 'FDB56','Item_Weight']=8.75
df.loc[df.Item_Identifier == 'FDT28','Item_Weight']=13.3
df.loc[df.Item_Identifier == 'FDW57','Item_Weight']=8.31
df.loc[df.Item_Identifier == 'DRB48','Item_Weight']=16.75
df.loc[df.Item_Identifier == 'FDP09','Item_Weight']=19.75
df.loc[df.Item_Identifier == 'FDH14','Item_Weight']=17.1
df.loc[df.Item_Identifier == 'FDA47','Item_Weight']=10.5
df.loc[df.Item_Identifier == 'FDG12','Item_Weight']=6.635
df.loc[df.Item_Identifier == 'DRK49','Item_Weight']=14.15
df.loc[df.Item_Identifier == 'FDD03','Item_Weight']=13.3
df.loc[df.Item_Identifier == 'FDS52','Item_Weight']=8.89
df.loc[df.Item_Identifier == 'FDV11','Item_Weight']=9.1
df.loc[df.Item_Identifier == 'FDD17','Item_Weight']=7.5
df.loc[df.Item_Identifier == 'FDZ16','Item_Weight']=16.85
df.loc[df.Item_Identifier == 'FDZ46','Item_Weight']=7.485
df.loc[df.Item_Identifier == 'DRA12','Item_Weight']=11.6
df.loc[df.Item_Identifier == 'FDY58','Item_Weight']=11.65
df.loc[df.Item_Identifier == 'NCF19','Item_Weight']=13
df.loc[df.Item_Identifier == 'DRJ13','Item_Weight']=12.65
df.loc[df.Item_Identifier == 'FDB14','Item_Weight']=20.25
df.loc[df.Item_Identifier == 'FDJ38','Item_Weight']=8.6
df.loc[df.Item_Identifier == 'FDW11','Item_Weight']=12.6
df.loc[df.Item_Identifier == 'FDL40','Item_Weight']=17.7
df.loc[df.Item_Identifier == 'DRI49','Item_Weight']=14.15
df.loc[df.Item_Identifier == 'DRG23','Item_Weight']=8.88
df.loc[df.Item_Identifier == 'NCP30','Item_Weight']=20.5
df.loc[df.Item_Identifier == 'NCH54','Item_Weight']=13.5
df.loc[df.Item_Identifier == 'NCO26','Item_Weight']=7.235
df.loc[df.Item_Identifier == 'FDB51','Item_Weight']=6.92
df.loc[df.Item_Identifier == 'FDX44','Item_Weight']=9.3
df.loc[df.Item_Identifier == 'NCN07','Item_Weight']=18.5
df.loc[df.Item_Identifier == 'NCC31','Item_Weight']=8.02
df.loc[df.Item_Identifier == 'NCO55','Item_Weight']=12.8
df.loc[df.Item_Identifier == 'NCC30','Item_Weight']=16.6
df.loc[df.Item_Identifier == 'FDI16','Item_Weight']=14
df.loc[df.Item_Identifier == 'FDP16','Item_Weight']=18.6
df.loc[df.Item_Identifier == 'FDB11','Item_Weight']=16
df.loc[df.Item_Identifier == 'NCB06','Item_Weight']=17.6
df.loc[df.Item_Identifier == 'FDA45','Item_Weight']=21.25
df.loc[df.Item_Identifier == 'DRJ25','Item_Weight']=14.6
df.loc[df.Item_Identifier == 'FDI04','Item_Weight']=13.65
df.loc[df.Item_Identifier == 'FDX20','Item_Weight']=7.365
df.loc[df.Item_Identifier == 'NCI18','Item_Weight']=18.35
df.loc[df.Item_Identifier == 'FDB36','Item_Weight']=5.465
df.loc[df.Item_Identifier == 'FDN13','Item_Weight']=18.6
df.loc[df.Item_Identifier == 'DRD24','Item_Weight']=13.85
df.loc[df.Item_Identifier == 'FDQ28','Item_Weight']=14
df.loc[df.Item_Identifier == 'FDM22','Item_Weight']=14
df.loc[df.Item_Identifier == 'DRF49','Item_Weight']=7.27
df.loc[df.Item_Identifier == 'FDW51','Item_Weight']=6.155
df.loc[df.Item_Identifier == 'DRL01','Item_Weight']=19.5
df.loc[df.Item_Identifier == 'FDP25','Item_Weight']=15.2
df.loc[df.Item_Identifier == 'NCM43','Item_Weight']=14.5
df.loc[df.Item_Identifier == 'FDK44','Item_Weight']=16.6
df.loc[df.Item_Identifier == 'FDM15','Item_Weight']=11.8
df.loc[df.Item_Identifier == 'FDS31','Item_Weight']=13.1
df.loc[df.Item_Identifier == 'FDI32','Item_Weight']=17.7
df.loc[df.Item_Identifier == 'FDR47','Item_Weight']=17.85
df.loc[df.Item_Identifier == 'FDB35','Item_Weight']=12.3
df.loc[df.Item_Identifier == 'NCU05','Item_Weight']=11.8
df.loc[df.Item_Identifier == 'FDO24','Item_Weight']=11.1
df.loc[df.Item_Identifier == 'FDV39','Item_Weight']=11.3
df.loc[df.Item_Identifier == 'FDU50','Item_Weight']=5.75
df.loc[df.Item_Identifier == 'FDK58','Item_Weight']=11.35
df.loc[df.Item_Identifier == 'NCW29','Item_Weight']=14
df.loc[df.Item_Identifier == 'FDE04','Item_Weight']=19.75
df.loc[df.Item_Identifier == 'NCB19','Item_Weight']=6.525
df.loc[df.Item_Identifier == 'FDV15','Item_Weight']=10.3
df.loc[df.Item_Identifier == 'FDL58','Item_Weight']=5.78
df.loc[df.Item_Identifier == 'FDA08','Item_Weight']=11.85
df.loc[df.Item_Identifier == 'FDT43','Item_Weight']=16.35
df.loc[df.Item_Identifier == 'FDT20','Item_Weight']=10.5
df.loc[df.Item_Identifier == 'FDB41','Item_Weight']=19
df.loc[df.Item_Identifier == 'NCN55','Item_Weight']=14.6
df.loc[df.Item_Identifier == 'NCM53','Item_Weight']=18.75
df.loc[df.Item_Identifier == 'FDE36','Item_Weight']=5.26
df.loc[df.Item_Identifier == 'FDN57','Item_Weight']=18.25
df.loc[df.Item_Identifier == 'FDI19','Item_Weight']=15.1
df.loc[df.Item_Identifier == 'FDF24','Item_Weight']=15.5
df.loc[df.Item_Identifier == 'FDG52','Item_Weight']=13.65
df.loc[df.Item_Identifier == 'DRF36','Item_Weight']=16.1
df.loc[df.Item_Identifier == 'FDX40','Item_Weight']=12.85
df.loc[df.Item_Identifier == 'DRK12','Item_Weight']=9.5
df.loc[df.Item_Identifier == 'DRC27','Item_Weight']=13.8
df.loc[df.Item_Identifier == 'NCD30','Item_Weight']=19.7
df.loc[df.Item_Identifier == 'NCZ54','Item_Weight']=14.65
df.loc[df.Item_Identifier == 'FDE10','Item_Weight']=6.67
df.loc[df.Item_Identifier == 'FDR44','Item_Weight']=6.11
df.loc[df.Item_Identifier == 'FDP28','Item_Weight']=13.65
df.loc[df.Item_Identifier == 'FDX15','Item_Weight']=17.2
df.loc[df.Item_Identifier == 'FDA39','Item_Weight']=6.32
df.loc[df.Item_Identifier == 'FDY24','Item_Weight']=4.88
df.loc[df.Item_Identifier == 'FDC60','Item_Weight']=5.425
df.loc[df.Item_Identifier == 'FDH28','Item_Weight']=15.85
df.loc[df.Item_Identifier == 'FDT25','Item_Weight']=7.5
df.loc[df.Item_Identifier == 'FDS49','Item_Weight']=9
df.loc[df.Item_Identifier == 'FDL56','Item_Weight']=14.1
df.loc[df.Item_Identifier == 'FDF14','Item_Weight']=7.55
df.loc[df.Item_Identifier == 'NCR38','Item_Weight']=17.25
df.loc[df.Item_Identifier == 'NCR18','Item_Weight']=15.85
df.loc[df.Item_Identifier == 'NCU41','Item_Weight']=18.85
df.loc[df.Item_Identifier == 'FDY56','Item_Weight']=16.35
df.loc[df.Item_Identifier == 'DRJ51','Item_Weight']=14.1
df.loc[df.Item_Identifier == 'FDY25','Item_Weight']=12
df.loc[df.Item_Identifier == 'FDU44','Item_Weight']=12.15
df.loc[df.Item_Identifier == 'FDL43','Item_Weight']=10.1
df.loc[df.Item_Identifier == 'FDF05','Item_Weight']=17.5
df.loc[df.Item_Identifier == 'FDL20','Item_Weight']=17.1
df.loc[df.Item_Identifier == 'FDV32','Item_Weight']=7.785
df.loc[df.Item_Identifier == 'FDJ34','Item_Weight']=11.8
df.loc[df.Item_Identifier == 'FDG08','Item_Weight']=13.15
df.loc[df.Item_Identifier == 'FDW13','Item_Weight']=8.5
df.loc[df.Item_Identifier == 'FDY03','Item_Weight']=17.6
df.loc[df.Item_Identifier == 'FDS12','Item_Weight']=9.1
df.loc[df.Item_Identifier == 'FDJ55','Item_Weight']=12.8
df.loc[df.Item_Identifier == 'DRK01','Item_Weight']=7.63
df.loc[df.Item_Identifier == 'FDG28','Item_Weight']=9.285
df.loc[df.Item_Identifier == 'FDY38','Item_Weight']=13.6
df.loc[df.Item_Identifier == 'FDN01','Item_Weight']=8.895
df.loc[df.Item_Identifier == 'NCR54','Item_Weight']=16.35
df.loc[df.Item_Identifier == 'FDG29','Item_Weight']=17.6
df.loc[df.Item_Identifier == 'FDG24','Item_Weight']=7.975
df.loc[df.Item_Identifier == 'FDG59','Item_Weight']=15.85
df.loc[df.Item_Identifier == 'FDM28','Item_Weight']=15.7
df.loc[df.Item_Identifier == 'FDW04','Item_Weight']=8.985
df.loc[df.Item_Identifier == 'FDS26','Item_Weight']=20.35
df.loc[df.Item_Identifier == 'FDQ56','Item_Weight']=6.59
df.loc[df.Item_Identifier == 'FDK51','Item_Weight']=19.85
df.loc[df.Item_Identifier == 'FDL22','Item_Weight']=16.85
df.loc[df.Item_Identifier == 'FDY55','Item_Weight']=16.75
df.loc[df.Item_Identifier == 'FDZ32','Item_Weight']=7.785
df.loc[df.Item_Identifier == 'DRE49','Item_Weight']=20.75
df.loc[df.Item_Identifier == 'FDT39','Item_Weight']=6.26
df.loc[df.Item_Identifier == 'FDE08','Item_Weight']=18.2
df.loc[df.Item_Identifier == 'FDB57','Item_Weight']=20.25
df.loc[df.Item_Identifier == 'NCT54','Item_Weight']=8.695
df.loc[df.Item_Identifier == 'FDF20','Item_Weight']=12.85
df.loc[df.Item_Identifier == 'FDH27','Item_Weight']=7.075
df.loc[df.Item_Identifier == 'FDY59','Item_Weight']=8.195
df.loc[df.Item_Identifier == 'FDK36','Item_Weight']=7.09
df.loc[df.Item_Identifier == 'NCM31','Item_Weight']=6.095
df.loc[df.Item_Identifier == 'FDE33','Item_Weight']=19.35
df.loc[df.Item_Identifier == 'FDU36','Item_Weight']=6.15
df.loc[df.Item_Identifier == 'NCQ54','Item_Weight']=17.7
df.loc[df.Item_Identifier == 'DRE60','Item_Weight']=9.395
df.loc[df.Item_Identifier == 'DRP47','Item_Weight']=15.75
df.loc[df.Item_Identifier == 'FDB21','Item_Weight']=7.475
df.loc[df.Item_Identifier == 'FDR04','Item_Weight']=7.075
df.loc[df.Item_Identifier == 'FDX23','Item_Weight']=6.445
df.loc[df.Item_Identifier == 'FDX19','Item_Weight']=19.1
df.loc[df.Item_Identifier == 'FDD40','Item_Weight']=20.25
df.loc[df.Item_Identifier == 'FDA01','Item_Weight']=15
df.loc[df.Item_Identifier == 'FDS33','Item_Weight']=6.67
df.loc[df.Item_Identifier == 'FDB29','Item_Weight']=16.7
df.loc[df.Item_Identifier == 'FDF46','Item_Weight']=7.07
df.loc[df.Item_Identifier == 'FDA33','Item_Weight']=6.48
df.loc[df.Item_Identifier == 'FDC08','Item_Weight']=19
df.loc[df.Item_Identifier == 'FDB53','Item_Weight']=13.35
df.loc[df.Item_Identifier == 'FDX36','Item_Weight']=9.695
df.loc[df.Item_Identifier == 'DRD13','Item_Weight']=15
df.loc[df.Item_Identifier == 'FDC52','Item_Weight']=11.15
df.loc[df.Item_Identifier == 'FDB45','Item_Weight']=20.85
df.loc[df.Item_Identifier == 'NCK19','Item_Weight']=9.8
df.loc[df.Item_Identifier == 'FDV51','Item_Weight']=16.35
df.loc[df.Item_Identifier == 'FDZ35','Item_Weight']=9.6
df.loc[df.Item_Identifier == 'FDV59','Item_Weight']=13.35
df.loc[df.Item_Identifier == 'DRH39','Item_Weight']=20.7
df.loc[df.Item_Identifier == 'FDU55','Item_Weight']=16.2
df.loc[df.Item_Identifier == 'NCO43','Item_Weight']=5.5
df.loc[df.Item_Identifier == 'FDQ07','Item_Weight']=15.1
df.loc[df.Item_Identifier == 'FDF28','Item_Weight']=15.7
df.loc[df.Item_Identifier == 'FDM01','Item_Weight']=7.895
df.loc[df.Item_Identifier == 'FDR24','Item_Weight']=17.35
df.loc[df.Item_Identifier == 'NCY18','Item_Weight']=7.285
df.loc[df.Item_Identifier == 'NCY30','Item_Weight']=20.25
df.loc[df.Item_Identifier == 'DRI37','Item_Weight']=15.85
df.loc[df.Item_Identifier == 'FDL27','Item_Weight']=6.17
df.loc[df.Item_Identifier == 'NCO30','Item_Weight']=19.5
df.loc[df.Item_Identifier == 'NCB07','Item_Weight']=19.2
df.loc[df.Item_Identifier == 'FDX25','Item_Weight']=16.7
df.loc[df.Item_Identifier == 'FDP59','Item_Weight']=20.85
df.loc[df.Item_Identifier == 'FDR59','Item_Weight']=14.5
df.loc[df.Item_Identifier == 'FDT27','Item_Weight']=11.395
df.loc[df.Item_Identifier == 'DRI01','Item_Weight']=7.97
df.loc[df.Item_Identifier == 'FDU09','Item_Weight']=7.71
df.loc[df.Item_Identifier == 'FDH26','Item_Weight']=19.25
df.loc[df.Item_Identifier == 'FDH40','Item_Weight']=11.6
df.loc[df.Item_Identifier == 'DRN47','Item_Weight']=12.1
df.loc[df.Item_Identifier == 'NCO17','Item_Weight']=10
df.loc[df.Item_Identifier == 'FDX60','Item_Weight']=14.35
df.loc[df.Item_Identifier == 'FDT22','Item_Weight']=10.395
df.loc[df.Item_Identifier == 'FDG45','Item_Weight']=8.1
df.loc[df.Item_Identifier == 'FDD44','Item_Weight']=8.05
df.loc[df.Item_Identifier == 'FDS15','Item_Weight']=9.195
df.loc[df.Item_Identifier == 'FDL51','Item_Weight']=20.7
df.loc[df.Item_Identifier == 'FDL32','Item_Weight']=15.7
df.loc[df.Item_Identifier == 'NCA54','Item_Weight']=16.5
df.loc[df.Item_Identifier == 'FDX09','Item_Weight']=9
df.loc[df.Item_Identifier == 'FDO51','Item_Weight']=6.785
df.loc[df.Item_Identifier == 'FDW49','Item_Weight']=19.5
df.loc[df.Item_Identifier == 'FDB27','Item_Weight']=7.575
df.loc[df.Item_Identifier == 'FDF45','Item_Weight']=18.2
df.loc[df.Item_Identifier == 'FDV02','Item_Weight']=16.75
df.loc[df.Item_Identifier == 'FDY28','Item_Weight']=7.47
df.loc[df.Item_Identifier == 'FDP51','Item_Weight']=13.85
df.loc[df.Item_Identifier == 'FDL52','Item_Weight']=6.635
df.loc[df.Item_Identifier == 'FDB34','Item_Weight']=15.25
df.loc[df.Item_Identifier == 'FDC50','Item_Weight']=15.85
df.loc[df.Item_Identifier == 'FDT57','Item_Weight']=15.2
df.loc[df.Item_Identifier == 'FDY32','Item_Weight']=7.605
df.loc[df.Item_Identifier == 'FDW07','Item_Weight']=18
df.loc[df.Item_Identifier == 'NCF18','Item_Weight']=18.35
df.loc[df.Item_Identifier == 'FDN58','Item_Weight']=13.8
df.loc[df.Item_Identifier == 'FDG35','Item_Weight']=21.2
df.loc[df.Item_Identifier == 'FDY34','Item_Weight']=10.5
df.loc[df.Item_Identifier == 'NCE19','Item_Weight']=8.97
df.loc[df.Item_Identifier == 'NCJ29','Item_Weight']=10.6
df.loc[df.Item_Identifier == 'FDT59','Item_Weight']=13.65
df.loc[df.Item_Identifier == 'NCX41','Item_Weight']=19
df.loc[df.Item_Identifier == 'FDF22','Item_Weight']=6.865
df.loc[df.Item_Identifier == 'FDM60','Item_Weight']=10.8
df.loc[df.Item_Identifier == 'FDR02','Item_Weight']=16.7
df.loc[df.Item_Identifier == 'FDS48','Item_Weight']=15.15
df.loc[df.Item_Identifier == 'NCZ42','Item_Weight']=10.5
df.loc[df.Item_Identifier == 'FDZ38','Item_Weight']=17.6
df.loc[df.Item_Identifier == 'NCB55','Item_Weight']=15.7
df.loc[df.Item_Identifier == 'FDC15','Item_Weight']=18.1
df.loc[df.Item_Identifier == 'FDF11','Item_Weight']=10.195
df.loc[df.Item_Identifier == 'FDB44','Item_Weight']=6.655
df.loc[df.Item_Identifier == 'NCC06','Item_Weight']=19
df.loc[df.Item_Identifier == 'FDB17','Item_Weight']=13.15
df.loc[df.Item_Identifier == 'FDW43','Item_Weight']=20.1
df.loc[df.Item_Identifier == 'FDA27','Item_Weight']=20.35
df.loc[df.Item_Identifier == 'FDN32','Item_Weight']=17.5
df.loc[df.Item_Identifier == 'FDZ27','Item_Weight']=7.935
df.loc[df.Item_Identifier == 'FDU01','Item_Weight']=20.25
df.loc[df.Item_Identifier == 'FDF10','Item_Weight']=15.5
df.loc[df.Item_Identifier == 'DRI13','Item_Weight']=15.35
df.loc[df.Item_Identifier == 'NCR05','Item_Weight']=10.1
df.loc[df.Item_Identifier == 'FDI35','Item_Weight']=14
df.loc[df.Item_Identifier == 'FDX08','Item_Weight']=12.85
df.loc[df.Item_Identifier == 'NCJ18','Item_Weight']=12.35
df.loc[df.Item_Identifier == 'FDJ41','Item_Weight']=6.85
df.loc[df.Item_Identifier == 'FDU08','Item_Weight']=10.3
df.loc[df.Item_Identifier == 'DRH15','Item_Weight']=8.775
df.loc[df.Item_Identifier == 'NCV17','Item_Weight']=18.85
df.loc[df.Item_Identifier == 'FDE24','Item_Weight']=14.85
df.loc[df.Item_Identifier == 'FDH53','Item_Weight']=20.5
df.loc[df.Item_Identifier == 'FDZ13','Item_Weight']=7.84
df.loc[df.Item_Identifier == 'FDW28','Item_Weight']=18.25
df.loc[df.Item_Identifier == 'FDU46','Item_Weight']=10.3
df.loc[df.Item_Identifier == 'NCE43','Item_Weight']=12.5
df.loc[df.Item_Identifier == 'NCC42','Item_Weight']=15
df.loc[df.Item_Identifier == 'FDQ20','Item_Weight']=8.325
df.loc[df.Item_Identifier == 'FDA13','Item_Weight']=15.85
df.loc[df.Item_Identifier == 'FDZ15','Item_Weight']=13.1
df.loc[df.Item_Identifier == 'NCV42','Item_Weight']=6.26
df.loc[df.Item_Identifier == 'DRI51','Item_Weight']=17.25
df.loc[df.Item_Identifier == 'FDO28','Item_Weight']=5.765
df.loc[df.Item_Identifier == 'NCS54','Item_Weight']=13.6
df.loc[df.Item_Identifier == 'FDH16','Item_Weight']=10.5
df.loc[df.Item_Identifier == 'FDR52','Item_Weight']=12.65
df.loc[df.Item_Identifier == 'NCH06','Item_Weight']=12.3
df.loc[df.Item_Identifier == 'FDA36','Item_Weight']=5.985
df.loc[df.Item_Identifier == 'FDT09','Item_Weight']=15.15
df.loc[df.Item_Identifier == 'FDU25','Item_Weight']=12.35
df.loc[df.Item_Identifier == 'FDK41','Item_Weight']=14.3
df.loc[df.Item_Identifier == 'FDM24','Item_Weight']=6.135
df.loc[df.Item_Identifier == 'FDQ45','Item_Weight']=9.5
df.loc[df.Item_Identifier == 'DRK59','Item_Weight']=8.895
df.loc[df.Item_Identifier == 'FDR21','Item_Weight']=19.7
df.loc[df.Item_Identifier == 'FDT44','Item_Weight']=16.6
df.loc[df.Item_Identifier == 'FDH57','Item_Weight']=10.895
df.loc[df.Item_Identifier == 'NCP42','Item_Weight']=8.51
df.loc[df.Item_Identifier == 'FDN09','Item_Weight']=14.15
df.loc[df.Item_Identifier == 'FDP32','Item_Weight']=6.65
df.loc[df.Item_Identifier == 'FDV57','Item_Weight']=15.25
df.loc[df.Item_Identifier == 'FDA40','Item_Weight']=16
df.loc[df.Item_Identifier == 'NCG42','Item_Weight']=19.2
df.loc[df.Item_Identifier == 'NCK54','Item_Weight']=12.15
df.loc[df.Item_Identifier == 'FDE16','Item_Weight']=8.895
df.loc[df.Item_Identifier == 'FDB15','Item_Weight']=10.895
df.loc[df.Item_Identifier == 'FDC40','Item_Weight']=16
df.loc[df.Item_Identifier == 'FDK24','Item_Weight']=9.195
df.loc[df.Item_Identifier == 'FDW31','Item_Weight']=11.35
df.loc[df.Item_Identifier == 'NCM07','Item_Weight']=9.395
df.loc[df.Item_Identifier == 'FDQ37','Item_Weight']=20.75
df.loc[df.Item_Identifier == 'FDK28','Item_Weight']=5.695
df.loc[df.Item_Identifier == 'FDR43','Item_Weight']=18.2
df.loc[df.Item_Identifier == 'FDL48','Item_Weight']=19.35
df.loc[df.Item_Identifier == 'DRL23','Item_Weight']=18.35
df.loc[df.Item_Identifier == 'NCX42','Item_Weight']=6.36
df.loc[df.Item_Identifier == 'DRD37','Item_Weight']=9.8
df.loc[df.Item_Identifier == 'FDD08','Item_Weight']=8.3
df.loc[df.Item_Identifier == 'NCN18','Item_Weight']=8.895
df.loc[df.Item_Identifier == 'NCI29','Item_Weight']=8.6
df.loc[df.Item_Identifier == 'FDU52','Item_Weight']=7.56
df.loc[df.Item_Identifier == 'FDN16','Item_Weight']=12.6
df.loc[df.Item_Identifier == 'NCM55','Item_Weight']=15.6
df.loc[df.Item_Identifier == 'FDR49','Item_Weight']=8.71
df.loc[df.Item_Identifier == 'FDA16','Item_Weight']=6.695
df.loc[df.Item_Identifier == 'FDO04','Item_Weight']=16.6
df.loc[df.Item_Identifier == 'NCL19','Item_Weight']=15.35
df.loc[df.Item_Identifier == 'FDR60','Item_Weight']=14.3
df.loc[df.Item_Identifier == 'FDG53','Item_Weight']=10
df.loc[df.Item_Identifier == 'DRG01','Item_Weight']=14.8
df.loc[df.Item_Identifier == 'FDI27','Item_Weight']=8.71
df.loc[df.Item_Identifier == 'FDD29','Item_Weight']=12.15
df.loc[df.Item_Identifier == 'NCR41','Item_Weight']=17.85
df.loc[df.Item_Identifier == 'FDW44','Item_Weight']=9.5
df.loc[df.Item_Identifier == 'FDU21','Item_Weight']=11.8
df.loc[df.Item_Identifier == 'FDI14','Item_Weight']=14.1
df.loc[df.Item_Identifier == 'FDN39','Item_Weight']=19.35
df.loc[df.Item_Identifier == 'FDT31','Item_Weight']=19.75
df.loc[df.Item_Identifier == 'FDJ14','Item_Weight']=10.3
df.loc[df.Item_Identifier == 'FDU38','Item_Weight']=10.8
df.loc[df.Item_Identifier == 'FDS32','Item_Weight']=17.75
df.loc[df.Item_Identifier == 'DRH13','Item_Weight']=8.575
df.loc[df.Item_Identifier == 'DRF03','Item_Weight']=19.1
df.loc[df.Item_Identifier == 'FDJ20','Item_Weight']=20.7
df.loc[df.Item_Identifier == 'FDX22','Item_Weight']=6.785
df.loc[df.Item_Identifier == 'DRM11','Item_Weight']=6.57
df.loc[df.Item_Identifier == 'FDL25','Item_Weight']=6.92
df.loc[df.Item_Identifier == 'FDT08','Item_Weight']=13.65
df.loc[df.Item_Identifier == 'FDO22','Item_Weight']=13.5
df.loc[df.Item_Identifier == 'NCM41','Item_Weight']=16.5
df.loc[df.Item_Identifier == 'FDJ21','Item_Weight']=16.7
df.loc[df.Item_Identifier == 'FDC53','Item_Weight']=8.68
df.loc[df.Item_Identifier == 'FDQ09','Item_Weight']=7.235
df.loc[df.Item_Identifier == 'DRE25','Item_Weight']=15.35
df.loc[df.Item_Identifier == 'FDL08','Item_Weight']=10.8
df.loc[df.Item_Identifier == 'FDW03','Item_Weight']=5.63
df.loc[df.Item_Identifier == 'FDC17','Item_Weight']=12.15
df.loc[df.Item_Identifier == 'FDE34','Item_Weight']=9.195
df.loc[df.Item_Identifier == 'FDP10','Item_Weight']=19
df.loc[df.Item_Identifier == 'FDZ22','Item_Weight']=9.395
df.loc[df.Item_Identifier == 'NCF31','Item_Weight']=9.13
df.loc[df.Item_Identifier == 'FDG14','Item_Weight']=9
df.loc[df.Item_Identifier == 'NCH30','Item_Weight']=17.1
df.loc[df.Item_Identifier == 'FDR36','Item_Weight']=6.715
df.loc[df.Item_Identifier == 'NCJ30','Item_Weight']=5.82
df.loc[df.Item_Identifier == 'FDR08','Item_Weight']=18.7
df.loc[df.Item_Identifier == 'FDU04','Item_Weight']=7.93
df.loc[df.Item_Identifier == 'NCQ50','Item_Weight']=18.75
df.loc[df.Item_Identifier == 'DRK37','Item_Weight']=5
df.loc[df.Item_Identifier == 'FDK48','Item_Weight']=7.445
df.loc[df.Item_Identifier == 'FDV58','Item_Weight']=20.85
df.loc[df.Item_Identifier == 'FDZ52','Item_Weight']=19.2
df.loc[df.Item_Identifier == 'NCF42','Item_Weight']=17.35
df.loc[df.Item_Identifier == 'FDQ48','Item_Weight']=14.3
df.loc[df.Item_Identifier == 'FDR58','Item_Weight']=6.675
df.loc[df.Item_Identifier == 'NCE07','Item_Weight']=8.18
df.loc[df.Item_Identifier == 'FDK14','Item_Weight']=6.98
df.loc[df.Item_Identifier == 'NCQ41','Item_Weight']=14.8
df.loc[df.Item_Identifier == 'FDX46','Item_Weight']=12.3
df.loc[df.Item_Identifier == 'FDC35','Item_Weight']=7.435
df.loc[df.Item_Identifier == 'FDH45','Item_Weight']=15.1
df.loc[df.Item_Identifier == 'FDX33','Item_Weight']=9.195
df.loc[df.Item_Identifier == 'DRJ35','Item_Weight']=10.1
df.loc[df.Item_Identifier == 'FDO19','Item_Weight']=17.7
df.loc[df.Item_Identifier == 'FDP13','Item_Weight']=8.1
df.loc[df.Item_Identifier == 'FDP24','Item_Weight']=20.6
df.loc[df.Item_Identifier == 'NCQ42','Item_Weight']=20.35
df.loc[df.Item_Identifier == 'FDU14','Item_Weight']=17.75
df.loc[df.Item_Identifier == 'FDT32','Item_Weight']=19
df.loc[df.Item_Identifier == 'FDK20','Item_Weight']=12.6
df.loc[df.Item_Identifier == 'FDU13','Item_Weight']=8.355
df.loc[df.Item_Identifier == 'FDE58','Item_Weight']=18.5
df.loc[df.Item_Identifier == 'FDZ01','Item_Weight']=8.975
df.loc[df.Item_Identifier == 'FDM08','Item_Weight']=10.1
df.loc[df.Item_Identifier == 'FDS58','Item_Weight']=9.285
df.loc[df.Item_Identifier == 'FDZ26','Item_Weight']=11.6
df.loc[df.Item_Identifier == 'FDY51','Item_Weight']=12.5
df.loc[df.Item_Identifier == 'FDL34','Item_Weight']=16
df.loc[df.Item_Identifier == 'DRG39','Item_Weight']=14.15
df.loc[df.Item_Identifier == 'NCG43','Item_Weight']=20.2
df.loc[df.Item_Identifier == 'FDT01','Item_Weight']=13.65
df.loc[df.Item_Identifier == 'DRF01','Item_Weight']=5.655
df.loc[df.Item_Identifier == 'FDF53','Item_Weight']=20.75
df.loc[df.Item_Identifier == 'FDS45','Item_Weight']=5.175
df.loc[df.Item_Identifier == 'FDR20','Item_Weight']=20
df.loc[df.Item_Identifier == 'FDD38','Item_Weight']=16.75
df.loc[df.Item_Identifier == 'DRF15','Item_Weight']=18.35
df.loc[df.Item_Identifier == 'FDH32','Item_Weight']=12.8
df.loc[df.Item_Identifier == 'NCJ42','Item_Weight']=19.75
df.loc[df.Item_Identifier == 'NCL18','Item_Weight']=18.85
df.loc[df.Item_Identifier == 'FDW22','Item_Weight']=9.695
df.loc[df.Item_Identifier == 'FDE32','Item_Weight']=20.7
df.loc[df.Item_Identifier == 'FDJ08','Item_Weight']=11.1
df.loc[df.Item_Identifier == 'FDG38','Item_Weight']=8.975
df.loc[df.Item_Identifier == 'NCE31','Item_Weight']=7.67
df.loc[df.Item_Identifier == 'FDS19','Item_Weight']=13.8
df.loc[df.Item_Identifier == 'FDU11','Item_Weight']=4.785
df.loc[df.Item_Identifier == 'FDL02','Item_Weight']=20
df.loc[df.Item_Identifier == 'DRK23','Item_Weight']=8.395
df.loc[df.Item_Identifier == 'FDO27','Item_Weight']=6.175
df.loc[df.Item_Identifier == 'FDB16','Item_Weight']=8.21
df.loc[df.Item_Identifier == 'NCB18','Item_Weight']=19.6
df.loc[df.Item_Identifier == 'NCL53','Item_Weight']=7.5
df.loc[df.Item_Identifier == 'FDR16','Item_Weight']=5.845
df.loc[df.Item_Identifier == 'NCQ05','Item_Weight']=11.395
df.loc[df.Item_Identifier == 'FDF44','Item_Weight']=7.17
df.loc[df.Item_Identifier == 'FDK15','Item_Weight']=10.8
df.loc[df.Item_Identifier == 'FDU32','Item_Weight']=8.785
df.loc[df.Item_Identifier == 'FDG09','Item_Weight']=20.6
df.loc[df.Item_Identifier == 'FDE39','Item_Weight']=7.89
df.loc[df.Item_Identifier == 'FDU56','Item_Weight']=16.85
df.loc[df.Item_Identifier == 'NCH55','Item_Weight']=16.35
df.loc[df.Item_Identifier == 'NCQ02','Item_Weight']=12.6
df.loc[df.Item_Identifier == 'NCU17','Item_Weight']=5.32
df.loc[df.Item_Identifier == 'FDV37','Item_Weight']=13
df.loc[df.Item_Identifier == 'NCI43','Item_Weight']=19.85
df.loc[df.Item_Identifier == 'NCQ53','Item_Weight']=17.6
df.loc[df.Item_Identifier == 'NCT18','Item_Weight']=14.6
df.loc[df.Item_Identifier == 'FDM14','Item_Weight']=13.8
df.loc[df.Item_Identifier == 'FDX57','Item_Weight']=17.25
df.loc[df.Item_Identifier == 'NCV05','Item_Weight']=10.1
df.loc[df.Item_Identifier == 'FDX39','Item_Weight']=14.3
df.loc[df.Item_Identifier == 'FDA23','Item_Weight']=9.8
df.loc[df.Item_Identifier == 'NCV06','Item_Weight']=11.3
df.loc[df.Item_Identifier == 'DRI39','Item_Weight']=13.8
df.loc[df.Item_Identifier == 'FDH21','Item_Weight']=10.395
df.loc[df.Item_Identifier == 'FDR26','Item_Weight']=20.7
df.loc[df.Item_Identifier == 'FDG21','Item_Weight']=17.35
df.loc[df.Item_Identifier == 'NCQ38','Item_Weight']=16.35
df.loc[df.Item_Identifier == 'FDN20','Item_Weight']=19.35
df.loc[df.Item_Identifier == 'NCN29','Item_Weight']=15.2
df.loc[df.Item_Identifier == 'FDI28','Item_Weight']=14.3
df.loc[df.Item_Identifier == 'FDZ28','Item_Weight']=20
df.loc[df.Item_Identifier == 'FDU10','Item_Weight']=10.1
df.loc[df.Item_Identifier == 'FDS28','Item_Weight']=8.18
df.loc[df.Item_Identifier == 'FDJ03','Item_Weight']=12.35
df.loc[df.Item_Identifier == 'FDQ51','Item_Weight']=16
df.loc[df.Item_Identifier == 'NCK06','Item_Weight']=5.03
df.loc[df.Item_Identifier == 'FDY09','Item_Weight']=15.6
df.loc[df.Item_Identifier == 'FDA10','Item_Weight']=20.35
df.loc[df.Item_Identifier == 'FDO34','Item_Weight']=17.7
df.loc[df.Item_Identifier == 'FDF40','Item_Weight']=20.25
df.loc[df.Item_Identifier == 'FDY02','Item_Weight']=8.945
df.loc[df.Item_Identifier == 'FDB59','Item_Weight']=18.25
df.loc[df.Item_Identifier == 'FDO15','Item_Weight']=16.75
df.loc[df.Item_Identifier == 'FDB38','Item_Weight']=19.5
df.loc[df.Item_Identifier == 'FDY26','Item_Weight']=20.6
df.loc[df.Item_Identifier == 'DRE13','Item_Weight']=6.28
df.loc[df.Item_Identifier == 'FDD50','Item_Weight']=18.85
df.loc[df.Item_Identifier == 'FDV56','Item_Weight']=16.1
df.loc[df.Item_Identifier == 'NCR29','Item_Weight']=7.565
df.loc[df.Item_Identifier == 'FDZ04','Item_Weight']=9.31
df.loc[df.Item_Identifier == 'FDU16','Item_Weight']=19.25
df.loc[df.Item_Identifier == 'FDV07','Item_Weight']=9.5
df.loc[df.Item_Identifier == 'DRC12','Item_Weight']=17.85
df.loc[df.Item_Identifier == 'DRK39','Item_Weight']=7.02
df.loc[df.Item_Identifier == 'DRB25','Item_Weight']=12.3
df.loc[df.Item_Identifier == 'FDK26','Item_Weight']=5.46
df.loc[df.Item_Identifier == 'FDM52','Item_Weight']=15.1
df.loc[df.Item_Identifier == 'NCO06','Item_Weight']=19.25
df.loc[df.Item_Identifier == 'FDK34','Item_Weight']=13.35
df.loc[df.Item_Identifier == 'FDO45','Item_Weight']=13.15
df.loc[df.Item_Identifier == 'FDF08','Item_Weight']=14.3
df.loc[df.Item_Identifier == 'FDH58','Item_Weight']=12.3
df.loc[df.Item_Identifier == 'FDS03','Item_Weight']=7.825
df.loc[df.Item_Identifier == 'FDE02','Item_Weight']=8.71
df.loc[df.Item_Identifier == 'NCZ06','Item_Weight']=19.6
df.loc[df.Item_Identifier == 'FDR23','Item_Weight']=15.85
df.loc[df.Item_Identifier == 'FDY35','Item_Weight']=17.6
df.loc[df.Item_Identifier == 'FDG44','Item_Weight']=6.13
df.loc[df.Item_Identifier == 'FDQ23','Item_Weight']=6.55
df.loc[df.Item_Identifier == 'FDY22','Item_Weight']=16.5
df.loc[df.Item_Identifier == 'NCN41','Item_Weight']=17
df.loc[df.Item_Identifier == 'FDH20','Item_Weight']=16.1
df.loc[df.Item_Identifier == 'FDB09','Item_Weight']=16.25
df.loc[df.Item_Identifier == 'FDA09','Item_Weight']=13.35
df.loc[df.Item_Identifier == 'FDP03','Item_Weight']=5.15
df.loc[df.Item_Identifier == 'FDO13','Item_Weight']=7.865
df.loc[df.Item_Identifier == 'DRD49','Item_Weight']=9.895
df.loc[df.Item_Identifier == 'NCP50','Item_Weight']=17.35
df.loc[df.Item_Identifier == 'DRP35','Item_Weight']=18.85
df.loc[df.Item_Identifier == 'FDN23','Item_Weight']=6.575
df.loc[df.Item_Identifier == 'FDS44','Item_Weight']=12.65
df.loc[df.Item_Identifier == 'NCI54','Item_Weight']=15.2
df.loc[df.Item_Identifier == 'FDA21','Item_Weight']=13.65
df.loc[df.Item_Identifier == 'FDE35','Item_Weight']=7.06
df.loc[df.Item_Identifier == 'DRJ24','Item_Weight']=11.8
df.loc[df.Item_Identifier == 'NCO54','Item_Weight']=19.5
df.loc[df.Item_Identifier == 'FDV12','Item_Weight']=16.7
df.loc[df.Item_Identifier == 'FDQ31','Item_Weight']=5.785
df.loc[df.Item_Identifier == 'DRG15','Item_Weight']=6.13
df.loc[df.Item_Identifier == 'FDT21','Item_Weight']=7.42
df.loc[df.Item_Identifier == 'FDT10','Item_Weight']=16.7
df.loc[df.Item_Identifier == 'FDX26','Item_Weight']=17.7
df.loc[df.Item_Identifier == 'FDN02','Item_Weight']=16.5
df.loc[df.Item_Identifier == 'DRE27','Item_Weight']=11.85
df.loc[df.Item_Identifier == 'FDS27','Item_Weight']=10.195
df.loc[df.Item_Identifier == 'FDL46','Item_Weight']=20.35
df.loc[df.Item_Identifier == 'NCV30','Item_Weight']=20.2
df.loc[df.Item_Identifier == 'FDA51','Item_Weight']=8.05
df.loc[df.Item_Identifier == 'FDM46','Item_Weight']=7.365
df.loc[df.Item_Identifier == 'FDK02','Item_Weight']=12.5
df.loc[df.Item_Identifier == 'FDJ57','Item_Weight']=7.42
df.loc[df.Item_Identifier == 'NCB31','Item_Weight']=6.235
df.loc[df.Item_Identifier == 'FDT50','Item_Weight']=6.75
df.loc[df.Item_Identifier == 'NCY41','Item_Weight']=16.75
df.loc[df.Item_Identifier == 'FDJ60','Item_Weight']=19.35
df.loc[df.Item_Identifier == 'FDS21','Item_Weight']=19.85
df.loc[df.Item_Identifier == 'FDS47','Item_Weight']=16.75
df.loc[df.Item_Identifier == 'DRM48','Item_Weight']=15.2
df.loc[df.Item_Identifier == 'FDW46','Item_Weight']=13
df.loc[df.Item_Identifier == 'FDW27','Item_Weight']=5.86
df.loc[df.Item_Identifier == 'FDU40','Item_Weight']=20.85
df.loc[df.Item_Identifier == 'FDX35','Item_Weight']=5.035
df.loc[df.Item_Identifier == 'FDD51','Item_Weight']=11.15
df.loc[df.Item_Identifier == 'FDY27','Item_Weight']=6.38
df.loc[df.Item_Identifier == 'NCN06','Item_Weight']=8.39
df.loc[df.Item_Identifier == 'FDR57','Item_Weight']=5.675
df.loc[df.Item_Identifier == 'FDR19','Item_Weight']=13.5
df.loc[df.Item_Identifier == 'FDJ33','Item_Weight']=8.895
df.loc[df.Item_Identifier == 'FDA52','Item_Weight']=16.2
df.loc[df.Item_Identifier == 'FDR27','Item_Weight']=15.1
df.loc[df.Item_Identifier == 'NCK42','Item_Weight']=7.475
df.loc[df.Item_Identifier == 'NCI31','Item_Weight']=20
df.loc[df.Item_Identifier == 'FDX16','Item_Weight']=17.85
df.loc[df.Item_Identifier == 'NCA05','Item_Weight']=20.75
df.loc[df.Item_Identifier == 'DRG51','Item_Weight']=12.1
df.loc[df.Item_Identifier == 'NCR30','Item_Weight']=20.6
df.loc[df.Item_Identifier == 'DRM37','Item_Weight']=15.35
df.loc[df.Item_Identifier == 'FDN56','Item_Weight']=5.46
df.loc[df.Item_Identifier == 'FDC09','Item_Weight']=15.5
df.loc[df.Item_Identifier == 'NCZ41','Item_Weight']=19.85
df.loc[df.Item_Identifier == 'FDP19','Item_Weight']=11.5
df.loc[df.Item_Identifier == 'DRL11','Item_Weight']=10.5
df.loc[df.Item_Identifier == 'FDO36','Item_Weight']=19.7
df.loc[df.Item_Identifier == 'FDF21','Item_Weight']=10.3
df.loc[df.Item_Identifier == 'FDS51','Item_Weight']=13.35
df.loc[df.Item_Identifier == 'FDE45','Item_Weight']=12.1
df.loc[df.Item_Identifier == 'FDX50','Item_Weight']=20.1
df.loc[df.Item_Identifier == 'FDQ21','Item_Weight']=21.25
df.loc[df.Item_Identifier == 'DRL37','Item_Weight']=15.5
df.loc[df.Item_Identifier == 'FDZ39','Item_Weight']=19.7
df.loc[df.Item_Identifier == 'FDH10','Item_Weight']=21
df.loc[df.Item_Identifier == 'NCO18','Item_Weight']=13.15
df.loc[df.Item_Identifier == 'FDD05','Item_Weight']=19.35
df.loc[df.Item_Identifier == 'FDZ23','Item_Weight']=17.75
df.loc[df.Item_Identifier == 'FDX27','Item_Weight']=20.7
df.loc[df.Item_Identifier == 'FDR14','Item_Weight']=11.65
df.loc[df.Item_Identifier == 'FDO01','Item_Weight']=21.1
df.loc[df.Item_Identifier == 'FDZ56','Item_Weight']=16.25
df.loc[df.Item_Identifier == 'NCL55','Item_Weight']=12.15
df.loc[df.Item_Identifier == 'FDD59','Item_Weight']=10.5
df.loc[df.Item_Identifier == 'DRF23','Item_Weight']=4.61
df.loc[df.Item_Identifier == 'FDT49','Item_Weight']=7
df.loc[df.Item_Identifier == 'FDH22','Item_Weight']=6.405
df.loc[df.Item_Identifier == 'FDT34','Item_Weight']=9.3
df.loc[df.Item_Identifier == 'FDB39','Item_Weight']=11.6
df.loc[df.Item_Identifier == 'FDQ22','Item_Weight']=16.75
df.loc[df.Item_Identifier == 'NCN43','Item_Weight']=12.15
df.loc[df.Item_Identifier == 'FDG57','Item_Weight']=14.7
df.loc[df.Item_Identifier == 'NCC43','Item_Weight']=7.39
df.loc[df.Item_Identifier == 'FDP01','Item_Weight']=20.75
df.loc[df.Item_Identifier == 'FDF52','Item_Weight']=9.3
df.loc[df.Item_Identifier == 'FDZ33','Item_Weight']=10.195
df.loc[df.Item_Identifier == 'FDW56','Item_Weight']=7.68
df.loc[df.Item_Identifier == 'FDC26','Item_Weight']=10.195
df.loc[df.Item_Identifier == 'FDF34','Item_Weight']=9.3
df.loc[df.Item_Identifier == 'FDD04','Item_Weight']=16
df.loc[df.Item_Identifier == 'NCJ31','Item_Weight']=19.2
df.loc[df.Item_Identifier == 'FDO57','Item_Weight']=20.75
df.loc[df.Item_Identifier == 'NCY05','Item_Weight']=13.5
df.loc[df.Item_Identifier == 'DRK11','Item_Weight']=8.21
df.loc[df.Item_Identifier == 'NCL30','Item_Weight']=18.1
df.loc[df.Item_Identifier == 'DRJ39','Item_Weight']=20.25
df.loc[df.Item_Identifier == 'FDZ44','Item_Weight']=8.185
df.loc[df.Item_Identifier == 'FDV46','Item_Weight']=18.2
df.loc[df.Item_Identifier == 'DRG03','Item_Weight']=14.5
df.loc[df.Item_Identifier == 'FDU37','Item_Weight']=9.5
df.loc[df.Item_Identifier == 'FDI57','Item_Weight']=19.85
df.loc[df.Item_Identifier == 'FDM45','Item_Weight']=8.655
df.loc[df.Item_Identifier == 'FDB26','Item_Weight']=14
df.loc[df.Item_Identifier == 'NCN26','Item_Weight']=10.85
df.loc[df.Item_Identifier == 'FDO38','Item_Weight']=17.25
df.loc[df.Item_Identifier == 'FDG31','Item_Weight']=12.15
df.loc[df.Item_Identifier == 'FDI45','Item_Weight']=13.1
df.loc[df.Item_Identifier == 'FDE17','Item_Weight']=20.1
df.loc[df.Item_Identifier == 'NCG06','Item_Weight']=16.35
df.loc[df.Item_Identifier == 'NCP29','Item_Weight']=8.42
df.loc[df.Item_Identifier == 'FDM02','Item_Weight']=12.5
df.loc[df.Item_Identifier == 'FDR46','Item_Weight']=16.85
df.loc[df.Item_Identifier == 'FDQ49','Item_Weight']=20.2
df.loc[df.Item_Identifier == 'FDS16','Item_Weight']=15.15
df.loc[df.Item_Identifier == 'FDU15','Item_Weight']=13.65
df.loc[df.Item_Identifier == 'FDO09','Item_Weight']=13.5
df.loc[df.Item_Identifier == 'FDB40','Item_Weight']=17.5
df.loc[df.Item_Identifier == 'DRN11','Item_Weight']=7.85
df.loc[df.Item_Identifier == 'FDE22','Item_Weight']=9.695
df.loc[df.Item_Identifier == 'FDF04','Item_Weight']=17.5
df.loc[df.Item_Identifier == 'FDE41','Item_Weight']=9.195
df.loc[df.Item_Identifier == 'NCD54','Item_Weight']=21.1
df.loc[df.Item_Identifier == 'FDN34','Item_Weight']=15.6
df.loc[df.Item_Identifier == 'FDL39','Item_Weight']=16.1
df.loc[df.Item_Identifier == 'FDH33','Item_Weight']=12.85
df.loc[df.Item_Identifier == 'FDA34','Item_Weight']=11.5
df.loc[df.Item_Identifier == 'DRH23','Item_Weight']=14.65
df.loc[df.Item_Identifier == 'FDD21','Item_Weight']=10.3
df.loc[df.Item_Identifier == 'FDK60','Item_Weight']=16.5
df.loc[df.Item_Identifier == 'FDY12','Item_Weight']=9.8
df.loc[df.Item_Identifier == 'FDP11','Item_Weight']=15.85
df.loc[df.Item_Identifier == 'NCF54','Item_Weight']=18
df.loc[df.Item_Identifier == 'FDV43','Item_Weight']=16
df.loc[df.Item_Identifier == 'DRE12','Item_Weight']=4.59
df.loc[df.Item_Identifier == 'NCW42','Item_Weight']=18.2
df.loc[df.Item_Identifier == 'FDI41','Item_Weight']=18.5
df.loc[df.Item_Identifier == 'FDV22','Item_Weight']=14.85
df.loc[df.Item_Identifier == 'FDQ46','Item_Weight']=7.51
df.loc[df.Item_Identifier == 'FDC44','Item_Weight']=15.6
df.loc[df.Item_Identifier == 'FDB22','Item_Weight']=8.02
df.loc[df.Item_Identifier == 'FDV23','Item_Weight']=11
df.loc[df.Item_Identifier == 'FDL33','Item_Weight']=7.235
df.loc[df.Item_Identifier == 'FDW48','Item_Weight']=18
df.loc[df.Item_Identifier == 'NCM06','Item_Weight']=7.475
df.loc[df.Item_Identifier == 'FDT46','Item_Weight']=11.35
df.loc[df.Item_Identifier == 'FDT38','Item_Weight']=18.7
df.loc[df.Item_Identifier == 'FDO40','Item_Weight']=17.1
df.loc[df.Item_Identifier == 'FDP12','Item_Weight']=9.8
df.loc[df.Item_Identifier == 'FDG16','Item_Weight']=15.25
df.loc[df.Item_Identifier == 'FDY11','Item_Weight']=6.71
df.loc[df.Item_Identifier == 'FDL38','Item_Weight']=13.8
df.loc[df.Item_Identifier == 'FDY60','Item_Weight']=10.5
df.loc[df.Item_Identifier == 'FDW40','Item_Weight']=14
df.loc[df.Item_Identifier == 'FDY08','Item_Weight']=9.395
df.loc[df.Item_Identifier == 'NCM42','Item_Weight']=6.13
df.loc[df.Item_Identifier == 'NCD07','Item_Weight']=9.1
df.loc[df.Item_Identifier == 'FDD09','Item_Weight']=13.5
df.loc[df.Item_Identifier == 'DRH59','Item_Weight']=10.8
df.loc[df.Item_Identifier == 'DRN36','Item_Weight']=15.2
df.loc[df.Item_Identifier == 'DRA24','Item_Weight']=19.35
df.loc[df.Item_Identifier == 'FDG34','Item_Weight']=11.5
df.loc[df.Item_Identifier == 'FDK22','Item_Weight']=9.8
df.loc[df.Item_Identifier == 'FDO33','Item_Weight']=14.75
df.loc[df.Item_Identifier == 'FDS10','Item_Weight']=19.2
df.loc[df.Item_Identifier == 'FDU34','Item_Weight']=18.25
df.loc[df.Item_Identifier == 'FDA26','Item_Weight']=7.855
df.loc[df.Item_Identifier == 'FDP38','Item_Weight']=10.1
df.loc[df.Item_Identifier == 'FDA50','Item_Weight']=16.25
df.loc[df.Item_Identifier == 'FDY10','Item_Weight']=17.6
df.loc[df.Item_Identifier == 'FDT19','Item_Weight']=7.59
df.loc[df.Item_Identifier == 'NCV54','Item_Weight']=11.1
df.loc[df.Item_Identifier == 'FDA28','Item_Weight']=16.1
df.loc[df.Item_Identifier == 'FDB05','Item_Weight']=5.155
df.loc[df.Item_Identifier == 'FDY52','Item_Weight']=6.365
df.loc[df.Item_Identifier == 'FDR48','Item_Weight']=11.65
df.loc[df.Item_Identifier == 'FDY15','Item_Weight']=18.25
df.loc[df.Item_Identifier == 'FDM51','Item_Weight']=11.8
df.loc[df.Item_Identifier == 'FDW09','Item_Weight']=13.65
df.loc[df.Item_Identifier == 'FDV44','Item_Weight']=8.365
df.loc[df.Item_Identifier == 'FDZ47','Item_Weight']=20.7
df.loc[df.Item_Identifier == 'NCP43','Item_Weight']=17.75
df.loc[df.Item_Identifier == 'FDL26','Item_Weight']=18
df.loc[df.Item_Identifier == 'DRM35','Item_Weight']=9.695
df.loc[df.Item_Identifier == 'DRD15','Item_Weight']=10.6
df.loc[df.Item_Identifier == 'FDV04','Item_Weight']=7.825
df.loc[df.Item_Identifier == 'NCN05','Item_Weight']=8.235
df.loc[df.Item_Identifier == 'FDJ02','Item_Weight']=17.2
df.loc[df.Item_Identifier == 'NCK17','Item_Weight']=11
df.loc[df.Item_Identifier == 'FDO58','Item_Weight']=19.6
df.loc[df.Item_Identifier == 'FDG33','Item_Weight']=5.365
df.loc[df.Item_Identifier == 'NCZ05','Item_Weight']=8.485
df.loc[df.Item_Identifier == 'NCP54','Item_Weight']=15.35
df.loc[df.Item_Identifier == 'FDV01','Item_Weight']=19.2
df.loc[df.Item_Identifier == 'FDF57','Item_Weight']=14.5
df.loc[df.Item_Identifier == 'FDA02','Item_Weight']=14
df.loc[df.Item_Identifier == 'DRJ37','Item_Weight']=10.8
df.loc[df.Item_Identifier == 'NCP55','Item_Weight']=14.65
df.loc[df.Item_Identifier == 'FDK38','Item_Weight']=6.65
df.loc[df.Item_Identifier == 'NCZ30','Item_Weight']=6.59
df.loc[df.Item_Identifier == 'DRY23','Item_Weight']=9.395
df.loc[df.Item_Identifier == 'NCG19','Item_Weight']=20.25
df.loc[df.Item_Identifier == 'FDQ01','Item_Weight']=19.7
df.loc[df.Item_Identifier == 'FDL44','Item_Weight']=18.25
df.loc[df.Item_Identifier == 'DRM23','Item_Weight']=16.6
df.loc[df.Item_Identifier == 'NCE18','Item_Weight']=10
df.loc[df.Item_Identifier == 'DRZ24','Item_Weight']=7.535
df.loc[df.Item_Identifier == 'FDT48','Item_Weight']=4.92
df.loc[df.Item_Identifier == 'DRG11','Item_Weight']=6.385
df.loc[df.Item_Identifier == 'FDP60','Item_Weight']=17.35
df.loc[df.Item_Identifier == 'FDE05','Item_Weight']=10.895
df.loc[df.Item_Identifier == 'FDC32','Item_Weight']=18.35
df.loc[df.Item_Identifier == 'FDJ22','Item_Weight']=18.75
df.loc[df.Item_Identifier == 'NCH18','Item_Weight']=9.3
df.loc[df.Item_Identifier == 'DRC13','Item_Weight']=8.26
df.loc[df.Item_Identifier == 'FDG47','Item_Weight']=12.8
df.loc[df.Item_Identifier == 'NCT05','Item_Weight']=10.895
df.loc[df.Item_Identifier == 'FDN50','Item_Weight']=16.85
df.loc[df.Item_Identifier == 'FDU60','Item_Weight']=20
df.loc[df.Item_Identifier == 'FDX02','Item_Weight']=16
df.loc[df.Item_Identifier == 'DRF27','Item_Weight']=8.93
df.loc[df.Item_Identifier == 'FDQ59','Item_Weight']=9.8
df.loc[df.Item_Identifier == 'NCZ53','Item_Weight']=9.6
df.loc[df.Item_Identifier == 'FDD34','Item_Weight']=7.945
df.loc[df.Item_Identifier == 'FDY43','Item_Weight']=14.85
df.loc[df.Item_Identifier == 'FDG46','Item_Weight']=8.63
df.loc[df.Item_Identifier == 'FDN44','Item_Weight']=13.15
df.loc[df.Item_Identifier == 'FDD32','Item_Weight']=17.7
df.loc[df.Item_Identifier == 'FDA56','Item_Weight']=9.21
df.loc[df.Item_Identifier == 'FDT13','Item_Weight']=14.85
df.loc[df.Item_Identifier == 'NCY29','Item_Weight']=13.65
df.loc[df.Item_Identifier == 'NCA42','Item_Weight']=6.965
df.loc[df.Item_Identifier == 'FDG26','Item_Weight']=18.85
df.loc[df.Item_Identifier == 'FDH24','Item_Weight']=20.7
df.loc[df.Item_Identifier == 'FDT52','Item_Weight']=9.695
df.loc[df.Item_Identifier == 'FDT04','Item_Weight']=17.25
df.loc[df.Item_Identifier == 'NCL54','Item_Weight']=12.6
df.loc[df.Item_Identifier == 'FDW50','Item_Weight']=13.1
df.loc[df.Item_Identifier == 'FDQ32','Item_Weight']=17.85
df.loc[df.Item_Identifier == 'FDE29','Item_Weight']=8.905
df.loc[df.Item_Identifier == 'FDB37','Item_Weight']=20.25
df.loc[df.Item_Identifier == 'FDN46','Item_Weight']=7.21
df.loc[df.Item_Identifier == 'FDV28','Item_Weight']=16.1
df.loc[df.Item_Identifier == 'FDV40','Item_Weight']=17.35
df.loc[df.Item_Identifier == 'FDZ57','Item_Weight']=10
df.loc[df.Item_Identifier == 'FDY46','Item_Weight']=18.6
df.loc[df.Item_Identifier == 'FDX45','Item_Weight']=16.75
df.loc[df.Item_Identifier == 'FDB33','Item_Weight']=17.75
df.loc[df.Item_Identifier == 'FDT58','Item_Weight']=9
df.loc[df.Item_Identifier == 'NCL31','Item_Weight']=7.39
df.loc[df.Item_Identifier == 'FDJ44','Item_Weight']=12.3
df.loc[df.Item_Identifier == 'FDS50','Item_Weight']=17
df.loc[df.Item_Identifier == 'FDA49','Item_Weight']=19.7
df.loc[df.Item_Identifier == 'FDO50','Item_Weight']=16.25
df.loc[df.Item_Identifier == 'DRK13','Item_Weight']=11.8
df.loc[df.Item_Identifier == 'FDI20','Item_Weight']=19.1
df.loc[df.Item_Identifier == 'FDM36','Item_Weight']=11.65
df.loc[df.Item_Identifier == 'FDN12','Item_Weight']=15.6
df.loc[df.Item_Identifier == 'FDG17','Item_Weight']=6.865
df.loc[df.Item_Identifier == 'FDM32','Item_Weight']=20.5
df.loc[df.Item_Identifier == 'FDC51','Item_Weight']=10.895
df.loc[df.Item_Identifier == 'FDF16','Item_Weight']=7.3
df.loc[df.Item_Identifier == 'FDI46','Item_Weight']=9.5
df.loc[df.Item_Identifier == 'FDZ21','Item_Weight']=17.6
df.loc[df.Item_Identifier == 'DRF25','Item_Weight']=9
df.loc[df.Item_Identifier == 'FDH05','Item_Weight']=14.35
df.loc[df.Item_Identifier == 'FDD52','Item_Weight']=18.25
df.loc[df.Item_Identifier == 'FDR55','Item_Weight']=12.15
df.loc[df.Item_Identifier == 'FDP04','Item_Weight']=15.35
df.loc[df.Item_Identifier == 'FDQ14','Item_Weight']=9.27
df.loc[df.Item_Identifier == 'DRN59','Item_Weight']=15
df.loc[df.Item_Identifier == 'NCR06','Item_Weight']=12.5
df.loc[df.Item_Identifier == 'FDB58','Item_Weight']=10.5
df.loc[df.Item_Identifier == 'NCV41','Item_Weight']=14.35
df.loc[df.Item_Identifier == 'FDW19','Item_Weight']=12.35
df.loc[df.Item_Identifier == 'FDO56','Item_Weight']=10.195
df.loc[df.Item_Identifier == 'FDN10','Item_Weight']=11.5
df.loc[df.Item_Identifier == 'FDY20','Item_Weight']=12.5
df.loc[df.Item_Identifier == 'FDV34','Item_Weight']=10.695
df.loc[df.Item_Identifier == 'NCX18','Item_Weight']=14.15
df.loc[df.Item_Identifier == 'FDT12','Item_Weight']=6.215
df.loc[df.Item_Identifier == 'FDD57','Item_Weight']=18.1
df.loc[df.Item_Identifier == 'FDK45','Item_Weight']=11.65
df.loc[df.Item_Identifier == 'FDZ48','Item_Weight']=17.75
df.loc[df.Item_Identifier == 'FDZ31','Item_Weight']=15.35
df.loc[df.Item_Identifier == 'FDL21','Item_Weight']=15.85
df.loc[df.Item_Identifier == 'FDC39','Item_Weight']=7.405
df.loc[df.Item_Identifier == 'FDP45','Item_Weight']=15.7
df.loc[df.Item_Identifier == 'FDC56','Item_Weight']=7.72
df.loc[df.Item_Identifier == 'FDE59','Item_Weight']=12.15
df.loc[df.Item_Identifier == 'FDB04','Item_Weight']=11.35
df.loc[df.Item_Identifier == 'NCK05','Item_Weight']=20.1
df.loc[df.Item_Identifier == 'FDR03','Item_Weight']=15.7
df.loc[df.Item_Identifier == 'FDC59','Item_Weight']=16.7
df.loc[df.Item_Identifier == 'DRB13','Item_Weight']=6.115
df.loc[df.Item_Identifier == 'NCE54','Item_Weight']=20.7
df.loc[df.Item_Identifier == 'FDC10','Item_Weight']=9.8
df.loc[df.Item_Identifier == 'NCL29','Item_Weight']=9.695
df.loc[df.Item_Identifier == 'FDM57','Item_Weight']=11.65
df.loc[df.Item_Identifier == 'FDZ36','Item_Weight']=6.035
df.loc[df.Item_Identifier == 'FDX10','Item_Weight']=6.385
df.loc[df.Item_Identifier == 'FDO46','Item_Weight']=9.6
df.loc[df.Item_Identifier == 'FDD16','Item_Weight']=20.5
df.loc[df.Item_Identifier == 'FDY44','Item_Weight']=14.15
df.loc[df.Item_Identifier == 'DRH51','Item_Weight']=17.6
df.loc[df.Item_Identifier == 'FDI50','Item_Weight']=8.42
df.loc[df.Item_Identifier == 'FDB60','Item_Weight']=9.3
df.loc[df.Item_Identifier == 'FDA20','Item_Weight']=6.78
df.loc[df.Item_Identifier == 'DRF37','Item_Weight']=17.25
df.loc[df.Item_Identifier == 'FDJ26','Item_Weight']=15.3
df.loc[df.Item_Identifier == 'FDZ25','Item_Weight']=15.7
df.loc[df.Item_Identifier == 'FDZ58','Item_Weight']=17.85
df.loc[df.Item_Identifier == 'NCG18','Item_Weight']=15.3
df.loc[df.Item_Identifier == 'FDH50','Item_Weight']=15
df.loc[df.Item_Identifier == 'DRO35','Item_Weight']=13.85
df.loc[df.Item_Identifier == 'FDP52','Item_Weight']=18.7
df.loc[df.Item_Identifier == 'FDC05','Item_Weight']=13.1
df.loc[df.Item_Identifier == 'NCA41','Item_Weight']=16.75
df.loc[df.Item_Identifier == 'FDX56','Item_Weight']=17.1
df.loc[df.Item_Identifier == 'NCP02','Item_Weight']=7.105
df.loc[df.Item_Identifier == 'FDZ49','Item_Weight']=11
df.loc[df.Item_Identifier == 'NCJ17','Item_Weight']=7.68
df.loc[df.Item_Identifier == 'FDP48','Item_Weight']=7.52
df.loc[df.Item_Identifier == 'FDI53','Item_Weight']=8.895
df.loc[df.Item_Identifier == 'FDW02','Item_Weight']=4.805
df.loc[df.Item_Identifier == 'FDO48','Item_Weight']=15
df.loc[df.Item_Identifier == 'NCR53','Item_Weight']=12.15
df.loc[df.Item_Identifier == 'FDF56','Item_Weight']=16.7
df.loc[df.Item_Identifier == 'FDL57','Item_Weight']=15.1
df.loc[df.Item_Identifier == 'FDV52','Item_Weight']=20.7
df.loc[df.Item_Identifier == 'NCS41','Item_Weight']=12.85
df.loc[df.Item_Identifier == 'FDF12','Item_Weight']=8.235
df.loc[df.Item_Identifier == 'FDM13','Item_Weight']=6.425
df.loc[df.Item_Identifier == 'NCS42','Item_Weight']=8.6
df.loc[df.Item_Identifier == 'FDD47','Item_Weight']=7.6
df.loc[df.Item_Identifier == 'DRE03','Item_Weight']=19.6
df.loc[df.Item_Identifier == 'FDE20','Item_Weight']=11.35
df.loc[df.Item_Identifier == 'FDI33','Item_Weight']=16.5
df.loc[df.Item_Identifier == 'NCT06','Item_Weight']=17.1
df.loc[df.Item_Identifier == 'FDD10','Item_Weight']=20.6
df.loc[df.Item_Identifier == 'FDK52','Item_Weight']=18.25
df.loc[df.Item_Identifier == 'FDJ36','Item_Weight']=14.5
df.loc[df.Item_Identifier == 'NCK18','Item_Weight']=9.6
df.loc[df.Item_Identifier == 'FDB08','Item_Weight']=6.055
df.loc[df.Item_Identifier == 'FDX43','Item_Weight']=5.655
df.loc[df.Item_Identifier == 'FDU58','Item_Weight']=6.61
df.loc[df.Item_Identifier == 'NCT29','Item_Weight']=12.6
df.loc[df.Item_Identifier == 'NCB43','Item_Weight']=20.2
df.loc[df.Item_Identifier == 'FDR37','Item_Weight']=16.5
df.loc[df.Item_Identifier == 'FDG56','Item_Weight']=13.3
df.loc[df.Item_Identifier == 'FDL13','Item_Weight']=13.85
df.loc[df.Item_Identifier == 'FDQ03','Item_Weight']=15
df.loc[df.Item_Identifier == 'NCC55','Item_Weight']=10.695
df.loc[df.Item_Identifier == 'FDA25','Item_Weight']=16.5
df.loc[df.Item_Identifier == 'FDV33','Item_Weight']=9.6
df.loc[df.Item_Identifier == 'FDX47','Item_Weight']=6.55
df.loc[df.Item_Identifier == 'FDB02','Item_Weight']=9.695
df.loc[df.Item_Identifier == 'FDI56','Item_Weight']=7.325
df.loc[df.Item_Identifier == 'FDQ08','Item_Weight']=15.7
df.loc[df.Item_Identifier == 'DRJ49','Item_Weight']=6.865
df.loc[df.Item_Identifier == 'FDP26','Item_Weight']=7.785
df.loc[df.Item_Identifier == 'FDO32','Item_Weight']=6.36
df.loc[df.Item_Identifier == 'FDR34','Item_Weight']=17
df.loc[df.Item_Identifier == 'FDU59','Item_Weight']=5.78
df.loc[df.Item_Identifier == 'FDN31','Item_Weight']=11.5
df.loc[df.Item_Identifier == 'FDC03','Item_Weight']=8.575
df.loc[df.Item_Identifier == 'FDL14','Item_Weight']=8.115
df.loc[df.Item_Identifier == 'FDP39','Item_Weight']=12.65
df.loc[df.Item_Identifier == 'FDT11','Item_Weight']=5.94
df.loc[df.Item_Identifier == 'FDU48','Item_Weight']=18.85
df.loc[df.Item_Identifier == 'NCP06','Item_Weight']=20.7
df.loc[df.Item_Identifier == 'FDT45','Item_Weight']=15.85
df.loc[df.Item_Identifier == 'FDE56','Item_Weight']=17.25
df.loc[df.Item_Identifier == 'FDZ34','Item_Weight']=6.695
df.loc[df.Item_Identifier == 'NCM54','Item_Weight']=17.7
df.loc[df.Item_Identifier == 'FDV24','Item_Weight']=5.635
df.loc[df.Item_Identifier == 'FDD46','Item_Weight']=6.035
df.loc[df.Item_Identifier == 'FDQ39','Item_Weight']=14.8
df.loc[df.Item_Identifier == 'FDE11','Item_Weight']=17.7
df.loc[df.Item_Identifier == 'NCU54','Item_Weight']=8.88
df.loc[df.Item_Identifier == 'FDO60','Item_Weight']=20
df.loc[df.Item_Identifier == 'NCS06','Item_Weight']=7.935
df.loc[df.Item_Identifier == 'FDQ55','Item_Weight']=13.65
df.loc[df.Item_Identifier == 'NCO02','Item_Weight']=11.15
df.loc[df.Item_Identifier == 'FDB12','Item_Weight']=11.15
df.loc[df.Item_Identifier == 'FDT40','Item_Weight']=5.985
df.loc[df.Item_Identifier == 'NCO05','Item_Weight']=7.27
df.loc[df.Item_Identifier == 'FDR32','Item_Weight']=6.78
df.loc[df.Item_Identifier == 'FDM04','Item_Weight']=9.195
df.loc[df.Item_Identifier == 'FDH08','Item_Weight']=7.51
df.loc[df.Item_Identifier == 'FDZ08','Item_Weight']=12.5
df.loc[df.Item_Identifier == 'FDU03','Item_Weight']=18.7
df.loc[df.Item_Identifier == 'FDV08','Item_Weight']=7.35
df.loc[df.Item_Identifier == 'FDY49','Item_Weight']=17.2
df.loc[df.Item_Identifier == 'DRK47','Item_Weight']=7.905
df.loc[df.Item_Identifier == 'NCE06','Item_Weight']=5.825
df.loc[df.Item_Identifier == 'DRI47','Item_Weight']=14.7
df.loc[df.Item_Identifier == 'FDR35','Item_Weight']=12.5
df.loc[df.Item_Identifier == 'FDK03','Item_Weight']=12.6
df.loc[df.Item_Identifier == 'FDN48','Item_Weight']=13.35
df.loc[df.Item_Identifier == 'FDZ59','Item_Weight']=6.63
df.loc[df.Item_Identifier == 'FDL09','Item_Weight']=19.6
df.loc[df.Item_Identifier == 'FDL03','Item_Weight']=19.25
df.loc[df.Item_Identifier == 'NCG07','Item_Weight']=12.3
df.loc[df.Item_Identifier == 'FDP22','Item_Weight']=14.65
df.loc[df.Item_Identifier == 'FDL45','Item_Weight']=15.6
df.loc[df.Item_Identifier == 'FDC45','Item_Weight']=17
df.loc[df.Item_Identifier == 'FDI40','Item_Weight']=11.5
df.loc[df.Item_Identifier == 'FDQ11','Item_Weight']=5.695
df.loc[df.Item_Identifier == 'FDQ52','Item_Weight']=17
df.loc[df.Item_Identifier == 'FDJ27','Item_Weight']=17.7
df.loc[df.Item_Identifier == 'NCM18','Item_Weight']=13
df.loc[df.Item_Identifier == 'FDT26','Item_Weight']=18.85
df.loc[df.Item_Identifier == 'DRD60','Item_Weight']=15.7
df.loc[df.Item_Identifier == 'NCH07','Item_Weight']=13.15
df.loc[df.Item_Identifier == 'FDP44','Item_Weight']=16.5
df.loc[df.Item_Identifier == 'FDI48','Item_Weight']=11.85
df.loc[df.Item_Identifier == 'NCF06','Item_Weight']=6.235
df.loc[df.Item_Identifier == 'FDT24','Item_Weight']=12.35
df.loc[df.Item_Identifier == 'FDK08','Item_Weight']=9.195
df.loc[df.Item_Identifier == 'FDS11','Item_Weight']=7.05
df.loc[df.Item_Identifier == 'DRE15','Item_Weight']=13.35
df.loc[df.Item_Identifier == 'FDX21','Item_Weight']=7.05
df.loc[df.Item_Identifier == 'NCI42','Item_Weight']=18.75
df.loc[df.Item_Identifier == 'FDX37','Item_Weight']=16.2
df.loc[df.Item_Identifier == 'FDX14','Item_Weight']=13.1
df.loc[df.Item_Identifier == 'FDM09','Item_Weight']=11.15
df.loc[df.Item_Identifier == 'NCW54','Item_Weight']=7.5
df.loc[df.Item_Identifier == 'FDF47','Item_Weight']=20.85
df.loc[df.Item_Identifier == 'FDW12','Item_Weight']=8.315
df.loc[df.Item_Identifier == 'FDW24','Item_Weight']=6.8
df.loc[df.Item_Identifier == 'DRD01','Item_Weight']=12.1
df.loc[df.Item_Identifier == 'FDN25','Item_Weight']=7.895
df.loc[df.Item_Identifier == 'FDP20','Item_Weight']=19.85
df.loc[df.Item_Identifier == 'FDR45','Item_Weight']=10.8
df.loc[df.Item_Identifier == 'FDZ45','Item_Weight']=14.1
df.loc[df.Item_Identifier == 'FDB23','Item_Weight']=19.2
df.loc[df.Item_Identifier == 'FDC41','Item_Weight']=15.6
df.loc[df.Item_Identifier == 'NCM26','Item_Weight']=20.5
df.loc[df.Item_Identifier == 'FDW35','Item_Weight']=10.6
df.loc[df.Item_Identifier == 'FDK40','Item_Weight']=7.035
df.loc[df.Item_Identifier == 'NCL42','Item_Weight']=18.85
df.loc[df.Item_Identifier == 'FDC33','Item_Weight']=8.96
df.loc[df.Item_Identifier == 'FDY04','Item_Weight']=17.7
df.loc[df.Item_Identifier == 'NCG30','Item_Weight']=20.2
df.loc[df.Item_Identifier == 'NCH29','Item_Weight']=5.51
df.loc[df.Item_Identifier == 'FDV20','Item_Weight']=20.2
df.loc[df.Item_Identifier == 'NCM29','Item_Weight']=11.5
df.loc[df.Item_Identifier == 'FDD53','Item_Weight']=16.2
df.loc[df.Item_Identifier == 'FDI44','Item_Weight']=16.1
df.loc[df.Item_Identifier == 'FDU20','Item_Weight']=19.35
df.loc[df.Item_Identifier == 'NCP41','Item_Weight']=16.6
df.loc[df.Item_Identifier == 'FDS01','Item_Weight']=11.6
df.loc[df.Item_Identifier == 'FDJ28','Item_Weight']=12.3
df.loc[df.Item_Identifier == 'FDH44','Item_Weight']=19.1
df.loc[df.Item_Identifier == 'NCY54','Item_Weight']=8.43
df.loc[df.Item_Identifier == 'DRA59','Item_Weight']=8.27
df.loc[df.Item_Identifier == 'FDS55','Item_Weight']=7.02
df.loc[df.Item_Identifier == 'DRG49','Item_Weight']=7.81
df.loc[df.Item_Identifier == 'NCN19','Item_Weight']=13.1
df.loc[df.Item_Identifier == 'FDH09','Item_Weight']=12.6
df.loc[df.Item_Identifier == 'FDS25','Item_Weight']=6.885
df.loc[df.Item_Identifier == 'NCI30','Item_Weight']=20.25
df.loc[df.Item_Identifier == 'FDM33','Item_Weight']=15.6
df.loc[df.Item_Identifier == 'NCA53','Item_Weight']=11.395
df.loc[df.Item_Identifier == 'FDA04','Item_Weight']=11.3
df.loc[df.Item_Identifier == 'FDS56','Item_Weight']=5.785
df.loc[df.Item_Identifier == 'FDT07','Item_Weight']=5.82
df.loc[df.Item_Identifier == 'FDA38','Item_Weight']=5.44
df.loc[df.Item_Identifier == 'FDM56','Item_Weight']=16.7
df.loc[df.Item_Identifier == 'NCW18','Item_Weight']=15.1
df.loc[df.Item_Identifier == 'FDQ44','Item_Weight']=20.5
df.loc[df.Item_Identifier == 'FDQ34','Item_Weight']=10.85
df.loc[df.Item_Identifier == 'FDN08','Item_Weight']=7.72
df.loc[df.Item_Identifier == 'FDK10','Item_Weight']=5.785
df.loc[df.Item_Identifier == 'FDZ10','Item_Weight']=17.85
df.loc[df.Item_Identifier == 'DRG48','Item_Weight']=5.78
df.loc[df.Item_Identifier == 'NCH43','Item_Weight']=8.42
df.loc[df.Item_Identifier == 'FDD35','Item_Weight']=12.15
df.loc[df.Item_Identifier == 'FDR01','Item_Weight']=5.405
df.loc[df.Item_Identifier == 'FDS23','Item_Weight']=4.635
df.loc[df.Item_Identifier == 'FDJ53','Item_Weight']=10.5
df.loc[df.Item_Identifier == 'FDA32','Item_Weight']=14
df.loc[df.Item_Identifier == 'FDX01','Item_Weight']=10.1
df.loc[df.Item_Identifier == 'FDA48','Item_Weight']=12.1
df.loc[df.Item_Identifier == 'FDI09','Item_Weight']=20.75
df.loc[df.Item_Identifier == 'DRF13','Item_Weight']=12.1
df.loc[df.Item_Identifier == 'FDK25','Item_Weight']=11.6
df.loc[df.Item_Identifier == 'FDC20','Item_Weight']=10.65
df.loc[df.Item_Identifier == 'FDW32','Item_Weight']=18.35
df.loc[df.Item_Identifier == 'FDQ19','Item_Weight']=7.35
df.loc[df.Item_Identifier == 'FDV50','Item_Weight']=14.3
df.loc[df.Item_Identifier == 'DRG37','Item_Weight']=16.2
df.loc[df.Item_Identifier == 'FDE53','Item_Weight']=10.895
df.loc[df.Item_Identifier == 'FDS08','Item_Weight']=5.735
df.loc[df.Item_Identifier == 'FDG22','Item_Weight']=17.6
df.loc[df.Item_Identifier == 'FDJ50','Item_Weight']=8.645
df.loc[df.Item_Identifier == 'FDV35','Item_Weight']=19.5
df.loc[df.Item_Identifier == 'DRL35','Item_Weight']=15.7
df.loc[df.Item_Identifier == 'FDS24','Item_Weight']=20.85
df.loc[df.Item_Identifier == 'FDS13','Item_Weight']=6.465
df.loc[df.Item_Identifier == 'FDX59','Item_Weight']=10.195
df.loc[df.Item_Identifier == 'FDL36','Item_Weight']=15.1
df.loc[df.Item_Identifier == 'DRJ11','Item_Weight']=9.5
df.loc[df.Item_Identifier == 'NCW17','Item_Weight']=18
df.loc[df.Item_Identifier == 'DRH36','Item_Weight']=16.2
df.loc[df.Item_Identifier == 'NCA17','Item_Weight']=20.6
df.loc[df.Item_Identifier == 'FDG41','Item_Weight']=8.84
df.loc[df.Item_Identifier == 'FDR12','Item_Weight']=12.6
df.loc[df.Item_Identifier == 'NCN14','Item_Weight']=19.1
df.loc[df.Item_Identifier == 'NCS38','Item_Weight']=8.6
df.loc[df.Item_Identifier == 'FDQ16','Item_Weight']=19.7
df.loc[df.Item_Identifier == 'FDS40','Item_Weight']=15.35
df.loc[df.Item_Identifier == 'FDV31','Item_Weight']=9.8
df.loc[df.Item_Identifier == 'NCD42','Item_Weight']=16.5
df.loc[df.Item_Identifier == 'DRF60','Item_Weight']=10.8
df.loc[df.Item_Identifier == 'FDP34','Item_Weight']=12.85
df.loc[df.Item_Identifier == 'FDI02','Item_Weight']=15.7
df.loc[df.Item_Identifier == 'FDG50','Item_Weight']=7.405
df.loc[df.Item_Identifier == 'FDV48','Item_Weight']=9.195
df.loc[df.Item_Identifier == 'FDH02','Item_Weight']=7.27
df.loc[df.Item_Identifier == 'NCD43','Item_Weight']=8.85
df.loc[df.Item_Identifier == 'FDE46','Item_Weight']=18.6
df.loc[df.Item_Identifier == 'FDR40','Item_Weight']=9.1
df.loc[df.Item_Identifier == 'DRE48','Item_Weight']=8.43
df.loc[df.Item_Identifier == 'FDV60','Item_Weight']=20.2
df.loc[df.Item_Identifier == 'FDV16','Item_Weight']=7.75
df.loc[df.Item_Identifier == 'FDY19','Item_Weight']=19.75
df.loc[df.Item_Identifier == 'FDD41','Item_Weight']=6.765
df.loc[df.Item_Identifier == 'NCK07','Item_Weight']=10.65
df.loc[df.Item_Identifier == 'FDZ60','Item_Weight']=20.5
df.loc[df.Item_Identifier == 'FDW47','Item_Weight']=15
df.loc[df.Item_Identifier == 'FDR56','Item_Weight']=15.5
df.loc[df.Item_Identifier == 'FDX58','Item_Weight']=13.15
df.loc[df.Item_Identifier == 'DRH25','Item_Weight']=18.7
df.loc[df.Item_Identifier == 'FDS04','Item_Weight']=10.195
df.loc[df.Item_Identifier == 'FDK16','Item_Weight']=9.065
df.loc[df.Item_Identifier == 'NCU42','Item_Weight']=9
df.loc[df.Item_Identifier == 'FDS37','Item_Weight']=7.655
df.loc[df.Item_Identifier == 'FDS57','Item_Weight']=15.5
df.loc[df.Item_Identifier == 'FDI52','Item_Weight']=18.7
df.loc[df.Item_Identifier == 'FDG40','Item_Weight']=13.65
df.loc[df.Item_Identifier == 'FDU49','Item_Weight']=19.5
df.loc[df.Item_Identifier == 'NCM30','Item_Weight']=19.1
df.loc[df.Item_Identifier == 'DRO47','Item_Weight']=10.195
df.loc[df.Item_Identifier == 'NCY06','Item_Weight']=15.25
df.loc[df.Item_Identifier == 'NCL41','Item_Weight']=12.35
df.loc[df.Item_Identifier == 'FDM58','Item_Weight']=16.85
df.loc[df.Item_Identifier == 'FDW45','Item_Weight']=18
df.loc[df.Item_Identifier == 'FDI07','Item_Weight']=12.35
df.loc[df.Item_Identifier == 'DRL47','Item_Weight']=19.7
df.loc[df.Item_Identifier == 'FDW01','Item_Weight']=14.5
df.loc[df.Item_Identifier == 'NCF07','Item_Weight']=9
df.loc[df.Item_Identifier == 'FDL24','Item_Weight']=10.3
df.loc[df.Item_Identifier == 'FDD20','Item_Weight']=14.15
df.loc[df.Item_Identifier == 'FDF09','Item_Weight']=6.215
df.loc[df.Item_Identifier == 'FDY45','Item_Weight']=17.5
df.loc[df.Item_Identifier == 'FDX49','Item_Weight']=4.615
df.loc[df.Item_Identifier == 'FDE26','Item_Weight']=9.3
df.loc[df.Item_Identifier == 'FDD56','Item_Weight']=15.2
df.loc[df.Item_Identifier == 'FDQ13','Item_Weight']=11.1
df.loc[df.Item_Identifier == 'DRD25','Item_Weight']=6.135
df.loc[df.Item_Identifier == 'FDT16','Item_Weight']=9.895
df.loc[df.Item_Identifier == 'NCB54','Item_Weight']=8.76
df.loc[df.Item_Identifier == 'FDA31','Item_Weight']=7.1
df.loc[df.Item_Identifier == 'FDM12','Item_Weight']=16.7
df.loc[df.Item_Identifier == 'FDT03','Item_Weight']=21.25
df.loc[df.Item_Identifier == 'FDB49','Item_Weight']=8.3
df.loc[df.Item_Identifier == 'FDE47','Item_Weight']=14.15
df.loc[df.Item_Identifier == 'FDU23','Item_Weight']=12.15
df.loc[df.Item_Identifier == 'NCA30','Item_Weight']=19
df.loc[df.Item_Identifier == 'FDH41','Item_Weight']=9
df.loc[df.Item_Identifier == 'FDS43','Item_Weight']=11.65
df.loc[df.Item_Identifier == 'FDP37','Item_Weight']=15.6
df.loc[df.Item_Identifier == 'FDJ09','Item_Weight']=15
df.loc[df.Item_Identifier == 'FDX34','Item_Weight']=6.195
df.loc[df.Item_Identifier == 'DRD27','Item_Weight']=18.75
df.loc[df.Item_Identifier == 'FDI12','Item_Weight']=9.395
df.loc[df.Item_Identifier == 'FDQ33','Item_Weight']=13.35
df.loc[df.Item_Identifier == 'FDH34','Item_Weight']=8.63
df.loc[df.Item_Identifier == 'NCX30','Item_Weight']=16.7
df.loc[df.Item_Identifier == 'FDB20','Item_Weight']=7.72
df.loc[df.Item_Identifier == 'NCK29','Item_Weight']=5.615
df.loc[df.Item_Identifier == 'DRL60','Item_Weight']=8.52
df.loc[df.Item_Identifier == 'FDV09','Item_Weight']=12.1
df.loc[df.Item_Identifier == 'DRJ23','Item_Weight']=18.35
df.loc[df.Item_Identifier == 'FDQ26','Item_Weight']=13.5
df.loc[df.Item_Identifier == 'NCA06','Item_Weight']=20.5
df.loc[df.Item_Identifier == 'FDJ07','Item_Weight']=7.26
df.loc[df.Item_Identifier == 'FDP56','Item_Weight']=8.185
df.loc[df.Item_Identifier == 'FDQ12','Item_Weight']=12.65
df.loc[df.Item_Identifier == 'FDF26','Item_Weight']=6.825
df.loc[df.Item_Identifier == 'FDA11','Item_Weight']=7.75
df.loc[df.Item_Identifier == 'FDW38','Item_Weight']=5.325
df.loc[df.Item_Identifier == 'FDI21','Item_Weight']=5.59
df.loc[df.Item_Identifier == 'FDH12','Item_Weight']=9.6
df.loc[df.Item_Identifier == 'FDC21','Item_Weight']=14.6
df.loc[df.Item_Identifier == 'FDD02','Item_Weight']=16.6
df.loc[df.Item_Identifier == 'FDL28','Item_Weight']=10
df.loc[df.Item_Identifier == 'FDR10','Item_Weight']=17.6
df.loc[df.Item_Identifier == 'FDR15','Item_Weight']=9.3
df.loc[df.Item_Identifier == 'FDQ40','Item_Weight']=11.1
df.loc[df.Item_Identifier == 'FDS34','Item_Weight']=19.35
df.loc[df.Item_Identifier == 'FDT56','Item_Weight']=16
df.loc[df.Item_Identifier == 'NCX06','Item_Weight']=17.6
df.loc[df.Item_Identifier == 'DRM59','Item_Weight']=5.88
df.loc[df.Item_Identifier == 'FDW34','Item_Weight']=9.6
df.loc[df.Item_Identifier == 'FDU24','Item_Weight']=6.78
df.loc[df.Item_Identifier == 'FDX11','Item_Weight']=16
df.loc[df.Item_Identifier == 'FDF35','Item_Weight']=15
df.loc[df.Item_Identifier == 'FDD22','Item_Weight']=10
df.loc[df.Item_Identifier == 'FDT60','Item_Weight']=12
df.loc[df.Item_Identifier == 'NCQ06','Item_Weight']=13
df.loc[df.Item_Identifier == 'FDW37','Item_Weight']=19.2
df.loc[df.Item_Identifier == 'FDY33','Item_Weight']=14.5
df.loc[df.Item_Identifier == 'FDF17','Item_Weight']=5.19
df.loc[df.Item_Identifier == 'FDU22','Item_Weight']=12.35
df.loc[df.Item_Identifier == 'NCP53','Item_Weight']=14.75
df.loc[df.Item_Identifier == 'FDF29','Item_Weight']=15.1
df.loc[df.Item_Identifier == 'FDI10','Item_Weight']=8.51
df.loc[df.Item_Identifier == 'FDR09','Item_Weight']=18.25
df.loc[df.Item_Identifier == 'DRH03','Item_Weight']=17.25
df.loc[df.Item_Identifier == 'NCJ05','Item_Weight']=18.7
df.loc[df.Item_Identifier == 'FDO03','Item_Weight']=10.395
df.loc[df.Item_Identifier == 'FDM21','Item_Weight']=20.2
df.loc[df.Item_Identifier == 'FDD26','Item_Weight']=8.71
df.loc[df.Item_Identifier == 'FDO39','Item_Weight']=6.985
df.loc[df.Item_Identifier == 'FDX51','Item_Weight']=9.5
df.loc[df.Item_Identifier == 'FDC38','Item_Weight']=15.7
df.loc[df.Item_Identifier == 'FDP07','Item_Weight']=18.2
df.loc[df.Item_Identifier == 'FDK27','Item_Weight']=11
df.loc[df.Item_Identifier == 'FDP31','Item_Weight']=21.1
df.loc[df.Item_Identifier == 'NCO07','Item_Weight']=9.06
df.loc[df.Item_Identifier == 'NCL05','Item_Weight']=19.6
df.loc[df.Item_Identifier == 'FDM10','Item_Weight']=18.25
df.loc[df.Item_Identifier == 'FDD11','Item_Weight']=12.85
df.loc[df.Item_Identifier == 'FDN45','Item_Weight']=19.35
df.loc[df.Item_Identifier == 'FDW39','Item_Weight']=6.69
df.loc[df.Item_Identifier == 'FDJ04','Item_Weight']=18
df.loc[df.Item_Identifier == 'NCT42','Item_Weight']=5.88
df.loc[df.Item_Identifier == 'FDM25','Item_Weight']=10.695
df.loc[df.Item_Identifier == 'FDD45','Item_Weight']=8.615
df.loc[df.Item_Identifier == 'FDK56','Item_Weight']=9.695
df.loc[df.Item_Identifier == 'NCU18','Item_Weight']=15.1
df.loc[df.Item_Identifier == 'DRQ35','Item_Weight']=9.3
df.loc[df.Item_Identifier == 'FDJ48','Item_Weight']=11.3
df.loc[df.Item_Identifier == 'FDK09','Item_Weight']=15.2
df.loc[df.Item_Identifier == 'FDC57','Item_Weight']=20.1
df.loc[df.Item_Identifier == 'NCN42','Item_Weight']=20.25
df.loc[df.Item_Identifier == 'FDT55','Item_Weight']=13.6
df.loc[df.Item_Identifier == 'FDQ57','Item_Weight']=7.275
df.loc[df.Item_Identifier == 'FDM34','Item_Weight']=19
df.loc[df.Item_Identifier == 'DRD12','Item_Weight']=6.96
df.loc[df.Item_Identifier == 'FDJ16','Item_Weight']=9.195
df.loc[df.Item_Identifier == 'FDZ12','Item_Weight']=9.17
df.loc[df.Item_Identifier == 'FDI22','Item_Weight']=12.6
df.loc[df.Item_Identifier == 'NCC07','Item_Weight']=19.6
df.loc[df.Item_Identifier == 'FDM16','Item_Weight']=8.155
df.loc[df.Item_Identifier == 'FDT36','Item_Weight']=12.3
df.loc[df.Item_Identifier == 'FDH38','Item_Weight']=6.425
df.loc[df.Item_Identifier == 'FDC16','Item_Weight']=11.5
df.loc[df.Item_Identifier == 'FDW26','Item_Weight']=11.8
df.loc[df.Item_Identifier == 'FDT33','Item_Weight']=7.81
df.loc[df.Item_Identifier == 'FDU31','Item_Weight']=10.5
df.loc[df.Item_Identifier == 'DRJ01','Item_Weight']=6.135
df.loc[df.Item_Identifier == 'NCF43','Item_Weight']=8.51
df.loc[df.Item_Identifier == 'FDY47','Item_Weight']=8.6
df.loc[df.Item_Identifier == 'NCS53','Item_Weight']=14.5
df.loc[df.Item_Identifier == 'DRB24','Item_Weight']=8.785
df.loc[df.Item_Identifier == 'FDE23','Item_Weight']=17.6
df.loc[df.Item_Identifier == 'FDN21','Item_Weight']=18.6
df.loc[df.Item_Identifier == 'DRC25','Item_Weight']=5.73
df.loc[df.Item_Identifier == 'FDW60','Item_Weight']=5.44
df.loc[df.Item_Identifier == 'NCQ18','Item_Weight']=15.75
df.loc[df.Item_Identifier == 'NCE30','Item_Weight']=16
df.loc[df.Item_Identifier == 'FDW25','Item_Weight']=5.175
df.loc[df.Item_Identifier == 'NCY17','Item_Weight']=18.2
df.loc[df.Item_Identifier == 'NCS18','Item_Weight']=12.65
df.loc[df.Item_Identifier == 'FDZ40','Item_Weight']=8.935
df.loc[df.Item_Identifier == 'FDB32','Item_Weight']=20.6
df.loc[df.Item_Identifier == 'FDG10','Item_Weight']=6.63
df.loc[df.Item_Identifier == 'FDF38','Item_Weight']=11.8
df.loc[df.Item_Identifier == 'FDY57','Item_Weight']=20.2
df.loc[df.Item_Identifier == 'FDY16','Item_Weight']=18.35
df.loc[df.Item_Identifier == 'DRH49','Item_Weight']=19.7
df.loc[df.Item_Identifier == 'FDA22','Item_Weight']=7.435
df.loc[df.Item_Identifier == 'FDV03','Item_Weight']=17.6
df.loc[df.Item_Identifier == 'FDP27','Item_Weight']=8.155
df.loc[df.Item_Identifier == 'FDZ20','Item_Weight']=16.1
df.loc[df.Item_Identifier == 'FDZ37','Item_Weight']=8.1
df.loc[df.Item_Identifier == 'FDL10','Item_Weight']=8.395
df.loc[df.Item_Identifier == 'FDF33','Item_Weight']=7.97
df.loc[df.Item_Identifier == 'FDQ27','Item_Weight']=5.19
df.loc[df.Item_Identifier == 'NCQ29','Item_Weight']=12
df.loc[df.Item_Identifier == 'NCI55','Item_Weight']=18.6
df.loc[df.Item_Identifier == 'FDD14','Item_Weight']=20.7
df.loc[df.Item_Identifier == 'NCD18','Item_Weight']=16
df.loc[df.Item_Identifier == 'NCE55','Item_Weight']=8.92
df.loc[df.Item_Identifier == 'NCQ43','Item_Weight']=17.75
df.loc[df.Item_Identifier == 'FDX48','Item_Weight']=17.75
df.loc[df.Item_Identifier == 'DRF48','Item_Weight']=5.73
df.loc[df.Item_Identifier == 'FDU51','Item_Weight']=20.2
df.loc[df.Item_Identifier == 'NCC19','Item_Weight']=6.57
df.loc[df.Item_Identifier == 'NCO29','Item_Weight']=11.15
df.loc[df.Item_Identifier == 'FDX55','Item_Weight']=15.1
df.loc[df.Item_Identifier == 'FDZ19','Item_Weight']=6.425
df.loc[df.Item_Identifier == 'FDY36','Item_Weight']=12.3
df.loc[df.Item_Identifier == 'FDL16','Item_Weight']=12.85
df.loc[df.Item_Identifier == 'NCV53','Item_Weight']=8.27
df.loc[df.Item_Identifier == 'FDA35','Item_Weight']=14.85
df.loc[df.Item_Identifier == 'FDX24','Item_Weight']=8.355
df.loc[df.Item_Identifier == 'NCS05','Item_Weight']=11.5
df.loc[df.Item_Identifier == 'FDK04','Item_Weight']=7.36
df.loc[df.Item_Identifier == 'FDI58','Item_Weight']=7.64
df.loc[df.Item_Identifier == 'FDJ45','Item_Weight']=17.75
df.loc[df.Item_Identifier == 'FDW21','Item_Weight']=5.34
df.loc[df.Item_Identifier == 'NCZ17','Item_Weight']=12.15
df.loc[df.Item_Identifier == 'FDG58','Item_Weight']=10.695
df.loc[df.Item_Identifier == 'FDI60','Item_Weight']=7.22
df.loc[df.Item_Identifier == 'FDW52','Item_Weight']=14
df.loc[df.Item_Identifier == 'FDN38','Item_Weight']=6.615
df.loc[df.Item_Identifier == 'FDU39','Item_Weight']=18.85
df.loc[df.Item_Identifier == 'FDR25','Item_Weight']=17
df.loc[df.Item_Identifier == 'FDM44','Item_Weight']=12.5
df.loc[df.Item_Identifier == 'DRM47','Item_Weight']=9.3
df.loc[df.Item_Identifier == 'NCA29','Item_Weight']=10.5
df.loc[df.Item_Identifier == 'NCJ43','Item_Weight']=6.635
df.loc[df.Item_Identifier == 'FDW15','Item_Weight']=15.35
df.loc[df.Item_Identifier == 'FDO20','Item_Weight']=12.85
df.loc[df.Item_Identifier == 'FDJ56','Item_Weight']=8.985
df.loc[df.Item_Identifier == 'NCR50','Item_Weight']=20.2
df.loc[df.Item_Identifier == 'FDN28','Item_Weight']=5.88
df.loc[df.Item_Identifier == 'FDY13','Item_Weight']=12.1
df.loc[df.Item_Identifier == 'NCM17','Item_Weight']=7.93
df.loc[df.Item_Identifier == 'FDB52','Item_Weight']=17.75
df.loc[df.Item_Identifier == 'FDS07','Item_Weight']=12.35
df.loc[df.Item_Identifier == 'FDO31','Item_Weight']=6.76
df.loc[df.Item_Identifier == 'FDP57','Item_Weight']=17.5
df.loc[df.Item_Identifier == 'FDO21','Item_Weight']=11.6
df.loc[df.Item_Identifier == 'FDW58','Item_Weight']=20.75
df.loc[df.Item_Identifier == 'NCL07','Item_Weight']=13.85
df.loc[df.Item_Identifier == 'FDU12','Item_Weight']=15.5
df.loc[df.Item_Identifier == 'FDO52','Item_Weight']=11.6
df.loc[df.Item_Identifier == 'FDI26','Item_Weight']=5.94
df.loc[df.Item_Identifier == 'FDO25','Item_Weight']=6.3
df.loc[df.Item_Identifier == 'FDV47','Item_Weight']=17.1
df.loc[df.Item_Identifier == 'FDF02','Item_Weight']=16.2
df.loc[df.Item_Identifier == 'DRG13','Item_Weight']=17.25
df.loc[df.Item_Identifier == 'FDD36','Item_Weight']=13.3
df.loc[df.Item_Identifier == 'FDI15','Item_Weight']=13.8
df.loc[df.Item_Identifier == 'NCN17','Item_Weight']=11
df.loc[df.Item_Identifier == 'FDN24','Item_Weight']=14.1
df.loc[df.Item_Identifier == 'FDG60','Item_Weight']=20.35
df.loc[df.Item_Identifier == 'DRH11','Item_Weight']=5.98
df.loc[df.Item_Identifier == 'FDJ15','Item_Weight']=11.35
df.loc[df.Item_Identifier == 'DRF51','Item_Weight']=15.75
df.loc[df.Item_Identifier == 'FDO37','Item_Weight']=8.06
df.loc[df.Item_Identifier == 'FDW10','Item_Weight']=21.2
df.loc[df.Item_Identifier == 'DRN37','Item_Weight']=9.6
df.loc[df.Item_Identifier == 'NCN53','Item_Weight']=5.175
df.loc[df.Item_Identifier == 'FDA37','Item_Weight']=7.81
df.loc[df.Item_Identifier == 'FDU35','Item_Weight']=6.44
df.loc[df.Item_Identifier == 'FDS59','Item_Weight']=14.8
df.loc[df.Item_Identifier == 'FDL15','Item_Weight']=17.85
df.loc[df.Item_Identifier == 'FDB28','Item_Weight']=6.615
df.loc[df.Item_Identifier == 'DRI11','Item_Weight']=8.26
df.loc[df.Item_Identifier == 'FDY37','Item_Weight']=17
df.loc[df.Item_Identifier == 'FDJ10','Item_Weight']=5.095
df.loc[df.Item_Identifier == 'FDW08','Item_Weight']=12.1
df.loc[df.Item_Identifier == 'FDP58','Item_Weight']=11.1
df.loc[df.Item_Identifier == 'FDF58','Item_Weight']=13.3
df.loc[df.Item_Identifier == 'FDB47','Item_Weight']=8.8
df.loc[df.Item_Identifier == 'FDV14','Item_Weight']=19.85
df.loc[df.Item_Identifier == 'FDC23','Item_Weight']=18
df.loc[df.Item_Identifier == 'FDU33','Item_Weight']=7.63
df.loc[df.Item_Identifier == 'DRO59','Item_Weight']=11.8
df.loc[df.Item_Identifier == 'FDD48','Item_Weight']=10.395
df.loc[df.Item_Identifier == 'NCK30','Item_Weight']=14.85
df.loc[df.Item_Identifier == 'FDW33','Item_Weight']=9.395
df.loc[df.Item_Identifier == 'FDT37','Item_Weight']=14.15
df.loc[df.Item_Identifier == 'FDS02','Item_Weight']=10.195
df.loc[df.Item_Identifier == 'FDP46','Item_Weight']=15.35
df.loc[df.Item_Identifier == 'NCC18','Item_Weight']=19.1
df.loc[df.Item_Identifier == 'FDU07','Item_Weight']=11.1
df.loc[df.Item_Identifier == 'FDE21','Item_Weight']=12.8
df.loc[df.Item_Identifier == 'FDX28','Item_Weight']=6.325
df.loc[df.Item_Identifier == 'FDY40','Item_Weight']=15.5
df.loc[df.Item_Identifier == 'FDX38','Item_Weight']=10.5
df.loc[df.Item_Identifier == 'FDI38','Item_Weight']=13.35
df.loc[df.Item_Identifier == 'NCX53','Item_Weight']=20.1
df.loc[df.Item_Identifier == 'NCN30','Item_Weight']=16.35
df.loc[df.Item_Identifier == 'FDK33','Item_Weight']=17.85
df.loc[df.Item_Identifier == 'FDU26','Item_Weight']=16.7
df.loc[df.Item_Identifier == 'FDR39','Item_Weight']=20.35
df.loc[df.Item_Identifier == 'NCG55','Item_Weight']=16.25
df.loc[df.Item_Identifier == 'FDZ43','Item_Weight']=11
df.loc[df.Item_Identifier == 'NCC54','Item_Weight']=17.75
df.loc[df.Item_Identifier == 'FDR33','Item_Weight']=7.31
df.loc[df.Item_Identifier == 'NCJ54','Item_Weight']=9.895
df.loc[df.Item_Identifier == 'FDT14','Item_Weight']=10.695
df.loc[df.Item_Identifier == 'DRL49','Item_Weight']=13.15
df.loc[df.Item_Identifier == 'FDO44','Item_Weight']=12.6
df.loc[df.Item_Identifier == 'NCT30','Item_Weight']=9.1
df.loc[df.Item_Identifier == 'FDS20','Item_Weight']=8.85
df.loc[df.Item_Identifier == 'FDA07','Item_Weight']=7.55
df.loc[df.Item_Identifier == 'NCW53','Item_Weight']=18.35
df.loc[df.Item_Identifier == 'FDZ51','Item_Weight']=11.3
df.loc[df.Item_Identifier == 'NCN54','Item_Weight']=20.35
df.loc[df.Item_Identifier == 'FDR11','Item_Weight']=10.5
df.loc[df.Item_Identifier == 'FDR51','Item_Weight']=9.035
df.loc[df.Item_Identifier == 'NCR42','Item_Weight']=9.105
df.loc[df.Item_Identifier == 'FDX04','Item_Weight']=19.6
df.loc[df.Item_Identifier == 'FDN03','Item_Weight']=9.8
df.loc[df.Item_Identifier == 'FDM03','Item_Weight']=12.65
df.loc[df.Item_Identifier == 'FDT23','Item_Weight']=7.72
df.loc[df.Item_Identifier == 'FDB50','Item_Weight']=13
df.loc[df.Item_Identifier == 'FDE50','Item_Weight']=19.7
df.loc[df.Item_Identifier == 'FDK55','Item_Weight']=18.5
df.loc[df.Item_Identifier == 'NCG54','Item_Weight']=12.1
df.loc[df.Item_Identifier == 'FDJ52','Item_Weight']=7.145
df.loc[df.Item_Identifier == 'FDA57','Item_Weight']=18.85
df.loc[df.Item_Identifier == 'FDA58','Item_Weight']=9.395
df.loc[df.Item_Identifier == 'DRB01','Item_Weight']=7.39
df.loc[df.Item_Identifier == 'NCZ29','Item_Weight']=15
df.loc[df.Item_Identifier == 'FDF50','Item_Weight']=4.905
df.loc[df.Item_Identifier == 'NCK31','Item_Weight']=10.895
df.loc[df.Item_Identifier == 'FDP40','Item_Weight']=4.555
df.loc[df.Item_Identifier == 'FDO11','Item_Weight']=8
df.loc[df.Item_Identifier == 'FDF39','Item_Weight']=14.85
df.loc[df.Item_Identifier == 'FDQ58','Item_Weight']=7.315
df.loc[df.Item_Identifier == 'FDA55','Item_Weight']=17.2
df.loc[df.Item_Identifier == 'FDA19','Item_Weight']=7.52
df.loc[df.Item_Identifier == 'FDQ36','Item_Weight']=7.855
df.loc[df.Item_Identifier == 'FDF59','Item_Weight']=12.5
df.loc[df.Item_Identifier == 'FDJ46','Item_Weight']=11.1
df.loc[df.Item_Identifier == 'FDX31','Item_Weight']=20.35
df.loc[df.Item_Identifier == 'FDP23','Item_Weight']=6.71
df.loc[df.Item_Identifier == 'FDC47','Item_Weight']=15
df.loc[df.Item_Identifier == 'FDC22','Item_Weight']=6.89
df.loc[df.Item_Identifier == 'FDD39','Item_Weight']=16.7
df.loc[df.Item_Identifier == 'DRC36','Item_Weight']=13
df.loc[df.Item_Identifier == 'DRE01','Item_Weight']=10.1
df.loc[df.Item_Identifier == 'NCS30','Item_Weight']=5.945
df.loc[df.Item_Identifier == 'FDH47','Item_Weight']=13.5
df.loc[df.Item_Identifier == 'FDP08','Item_Weight']=20.5
df.loc[df.Item_Identifier == 'FDC14','Item_Weight']=14.5
df.loc[df.Item_Identifier == 'NCY42','Item_Weight']=6.38
df.loc[df.Item_Identifier == 'FDE44','Item_Weight']=14.65
df.loc[df.Item_Identifier == 'DRE37','Item_Weight']=13.5
df.loc[df.Item_Identifier == 'FDE40','Item_Weight']=15.6
df.loc[df.Item_Identifier == 'FDJ12','Item_Weight']=8.895
df.loc[df.Item_Identifier == 'FDH48','Item_Weight']=13.5
df.loc[df.Item_Identifier == 'FDV36','Item_Weight']=18.7
df.loc[df.Item_Identifier == 'NCW41','Item_Weight']=18
df.loc[df.Item_Identifier == 'FDS35','Item_Weight']=9.3
df.loc[df.Item_Identifier == 'FDX12','Item_Weight']=18.2
df.loc[df.Item_Identifier == 'NCY53','Item_Weight']=20
df.loc[df.Item_Identifier == 'NCH42','Item_Weight']=6.86
df.loc[df.Item_Identifier == 'FDH46','Item_Weight']=6.935
df.loc[df.Item_Identifier == 'FDW36','Item_Weight']=11.15
df.loc[df.Item_Identifier == 'FDV26','Item_Weight']=20.25
df.loc[df.Item_Identifier == 'DRI03','Item_Weight']=6.03
df.loc[df.Item_Identifier == 'NCL06','Item_Weight']=14.65
df.loc[df.Item_Identifier == 'NCO14','Item_Weight']=9.6
df.loc[df.Item_Identifier == 'FDI08','Item_Weight']=18.2
df.loc[df.Item_Identifier == 'FDS14','Item_Weight']=7.285
df.loc[df.Item_Identifier == 'NCK53','Item_Weight']=11.6
df.loc[df.Item_Identifier == 'FDH56','Item_Weight']=9.8
df.loc[df.Item_Identifier == 'NCQ30','Item_Weight']=7.725
df.loc[df.Item_Identifier == 'FDG32','Item_Weight']=19.85
df.loc[df.Item_Identifier == 'FDY48','Item_Weight']=14
df.loc[df.Item_Identifier == 'NCU06','Item_Weight']=17.6
df.loc[df.Item_Identifier == 'FDM38','Item_Weight']=5.885
df.loc[df.Item_Identifier == 'FDA14','Item_Weight']=16.1
df.loc[df.Item_Identifier == 'FDT15','Item_Weight']=12.15
df.loc[df.Item_Identifier == 'NCJ19','Item_Weight']=18.6
df.loc[df.Item_Identifier == 'NCI06','Item_Weight']=11.3
df.loc[df.Item_Identifier == 'FDV19','Item_Weight']=14.85
df.loc[df.Item_Identifier == 'FDQ47','Item_Weight']=7.155
df.loc[df.Item_Identifier == 'FDC04','Item_Weight']=15.6
df.loc[df.Item_Identifier == 'FDR31','Item_Weight']=6.46
df.loc[df.Item_Identifier == 'NCW06','Item_Weight']=16.2
df.loc[df.Item_Identifier == 'FDO16','Item_Weight']=5.48
df.loc[df.Item_Identifier == 'DRN35','Item_Weight']=8.01
df.loc[df.Item_Identifier == 'FDV55','Item_Weight']=17.75
df.loc[df.Item_Identifier == 'FDB03','Item_Weight']=17.75
df.loc[df.Item_Identifier == 'FDC34','Item_Weight']=16
df.loc[df.Item_Identifier == 'FDM50','Item_Weight']=13
df.loc[df.Item_Identifier == 'FDD23','Item_Weight']=9.5
df.loc[df.Item_Identifier == 'FDX52','Item_Weight']=11.5
df.loc[df.Item_Identifier == 'FDO12','Item_Weight']=15.75
df.loc[df.Item_Identifier == 'NCJ06','Item_Weight']=20.1
df.loc[df.Item_Identifier == 'FDT35','Item_Weight']=19.85
df.loc[df.Item_Identifier == 'FDG05','Item_Weight']=11
df.loc[df.Item_Identifier == 'FDE28','Item_Weight']=9.5
df.loc[df.Item_Identifier == 'FDY50','Item_Weight']=5.8
df.loc[df.Item_Identifier == 'FDE57','Item_Weight']=9.6
df.loc[df.Item_Identifier == 'FDC11','Item_Weight']=20.5
df.loc[df.Item_Identifier == 'FDE14','Item_Weight']=13.65
df.loc[df.Item_Identifier == 'NCT41','Item_Weight']=15.7
df.loc[df.Item_Identifier == 'FDK32','Item_Weight']=16.25
df.loc[df.Item_Identifier == 'DRI23','Item_Weight']=18.85
df.loc[df.Item_Identifier == 'DRL59','Item_Weight']=16.75
df.loc[df.Item_Identifier == 'FDI34','Item_Weight']=10.65
df.loc[df.Item_Identifier == 'FDC58','Item_Weight']=10.195
df.loc[df.Item_Identifier == 'FDT02','Item_Weight']=12.6
df.loc[df.Item_Identifier == 'FDH04','Item_Weight']=6.115
df.loc[df.Item_Identifier == 'FDR07','Item_Weight']=21.35
df.loc[df.Item_Identifier == 'FDK46','Item_Weight']=9.6
df.loc[df.Item_Identifier == 'NCM05','Item_Weight']=6.825
df.loc[df.Item_Identifier == 'FDR22','Item_Weight']=19.35
df.loc[df.Item_Identifier == 'FDH60','Item_Weight']=19.7
df.loc[df.Item_Identifier == 'FDY39','Item_Weight']=5.305
df.loc[df.Item_Identifier == 'FDZ07','Item_Weight']=15.1
df.loc[df.Item_Identifier == 'NCX05','Item_Weight']=15.2
df.loc[df.Item_Identifier == 'NCF30','Item_Weight']=17
df.loc[df.Item_Identifier == 'FDN49','Item_Weight']=17.25
df.loc[df.Item_Identifier == 'DRC24','Item_Weight']=17.85
df.loc[df.Item_Identifier == 'FDS60','Item_Weight']=20.85
df.loc[df.Item_Identifier == 'FDZ02','Item_Weight']=6.905
df.loc[df.Item_Identifier == 'FDW16','Item_Weight']=17.35
df.loc[df.Item_Identifier == 'NCQ17','Item_Weight']=10.3
df.loc[df.Item_Identifier == 'NCO53','Item_Weight']=16.2
df.loc[df.Item_Identifier == 'FDU47','Item_Weight']=12.8
df.loc[df.Item_Identifier == 'FDK50','Item_Weight']=7.96
df.loc[df.Item_Identifier == 'NCE42','Item_Weight']=21.1
df.loc[df.Item_Identifier == 'FDZ09','Item_Weight']=17.6
df.loc[df.Item_Identifier == 'NCU30','Item_Weight']=5.11
df.loc[df.Item_Identifier == 'DRG36','Item_Weight']=14.15
df.loc[df.Item_Identifier == 'FDX03','Item_Weight']=15.85
df.loc[df.Item_Identifier == 'FDI24','Item_Weight']=10.3
df.loc[df.Item_Identifier == 'NCD31','Item_Weight']=12.1
df.loc[df.Item_Identifier == 'NCV29','Item_Weight']=11.8
df.loc[df.Item_Identifier == 'NCP17','Item_Weight']=19.35
df.loc[df.Item_Identifier == 'FDN60','Item_Weight']=15.1
df.loc[df.Item_Identifier == 'DRM49','Item_Weight']=6.11
df.loc[df.Item_Identifier == 'FDY14','Item_Weight']=10.3
df.loc[df.Item_Identifier == 'DRI59','Item_Weight']=9.5
df.loc[df.Item_Identifier == 'FDY01','Item_Weight']=11.8
df.loc[df.Item_Identifier == 'FDJ40','Item_Weight']=13.6
df.loc[df.Item_Identifier == 'FDQ15','Item_Weight']=20.35
df.loc[df.Item_Identifier == 'DRJ47','Item_Weight']=18.25
df.loc[df.Item_Identifier == 'FDW23','Item_Weight']=5.765
df.loc[df.Item_Identifier == 'FDC37','Item_Weight']=15.5
df.loc[df.Item_Identifier == 'NCO41','Item_Weight']=12.5
df.loc[df.Item_Identifier == 'FDU19','Item_Weight']=8.77
df.loc[df.Item_Identifier == 'FDD33','Item_Weight']=12.85
df.loc[df.Item_Identifier == 'FDT51','Item_Weight']=11.65
df.loc[df.Item_Identifier == 'FDY31','Item_Weight']=5.98
df.loc[df.Item_Identifier == 'NCS29','Item_Weight']=9
df.loc[df.Item_Identifier == 'FDB10','Item_Weight']=10
df.loc[df.Item_Identifier == 'NCU29','Item_Weight']=7.685
df.loc[df.Item_Identifier == 'NCP14','Item_Weight']=8.275
df.loc[df.Item_Identifier == 'FDC48','Item_Weight']=9.195
df.loc[df.Item_Identifier == 'FDM27','Item_Weight']=12.35
df.loc[df.Item_Identifier == 'FDW14','Item_Weight']=8.3
df.loc[df.Item_Identifier == 'FDS36','Item_Weight']=8.38
df.loc[df.Item_Identifier == 'NCA18','Item_Weight']=10.1
df.loc[df.Item_Identifier == 'FDI36','Item_Weight']=12.5
df.loc[df.Item_Identifier == 'FDI05','Item_Weight']=8.35
df.loc[df.Item_Identifier == 'FDE09','Item_Weight']=8.775
df.loc[df.Item_Identifier == 'NCO42','Item_Weight']=21.25
df.loc[df.Item_Identifier == 'FDS22','Item_Weight']=16.85
df.loc[df.Item_Identifier == 'FDQ25','Item_Weight']=8.63
df.loc[df.Item_Identifier == 'FDP21','Item_Weight']=7.42
df.loc[df.Item_Identifier == 'FDQ24','Item_Weight']=15.7
df.loc[df.Item_Identifier == 'FDN40','Item_Weight']=5.88
df.loc[df.Item_Identifier == 'FDH52','Item_Weight']=9.42
df.loc[df.Item_Identifier == 'NCV18','Item_Weight']=6.775
df.loc[df.Item_Identifier == 'FDQ04','Item_Weight']=6.4
df.loc[df.Item_Identifier == 'FDS39','Item_Weight']=6.895
df.loc[df.Item_Identifier == 'FDU27','Item_Weight']=18.6
df.loc[df.Item_Identifier == 'FDT47','Item_Weight']=5.26
df.loc[df.Item_Identifier == 'FDP15','Item_Weight']=15.2
df.loc[df.Item_Identifier == 'FDW55','Item_Weight']=12.6
df.loc[df.Item_Identifier == 'FDU45','Item_Weight']=15.6
df.loc[df.Item_Identifier == 'DRG25','Item_Weight']=10.5
df.loc[df.Item_Identifier == 'FDN51','Item_Weight']=17.85
df.loc[df.Item_Identifier == 'FDU57','Item_Weight']=8.27
df.loc[df.Item_Identifier == 'FDB46','Item_Weight']=10.5
df.loc[df.Item_Identifier == 'NCX17','Item_Weight']=21.25
df.loc[df.Item_Identifier == 'FDW59','Item_Weight']=13.15
df.loc[df.Item_Identifier == 'NCT17','Item_Weight']=10.8
df.loc[df.Item_Identifier == 'FDZ14','Item_Weight']=7.71
df.loc[df.Item_Identifier == 'FDV21','Item_Weight']=11.5
df.loc[df.Item_Identifier == 'FDH31','Item_Weight']=12
df.loc[df.Item_Identifier == 'NCM19','Item_Weight']=12.65
df.loc[df.Item_Identifier == 'FDX13','Item_Weight']=7.725
df.loc[df.Item_Identifier == 'FDJ32','Item_Weight']=10.695
df.loc[df.Item_Identifier == 'FDV13','Item_Weight']=17.35
df.loc[df.Item_Identifier == 'NCU53','Item_Weight']=5.485
df.loc[df.Item_Identifier == 'FDE38','Item_Weight']=6.52
df.loc[df.Item_Identifier == 'NCD55','Item_Weight']=14
df.loc[df.Item_Identifier == 'FDZ50','Item_Weight']=12.8
df.loc[df.Item_Identifier == 'DRC49','Item_Weight']=8.67
df.loc[df.Item_Identifier == 'FDC28','Item_Weight']=7.905
df.loc[df.Item_Identifier == 'FDO08','Item_Weight']=11.1
df.loc[df.Item_Identifier == 'FDD28','Item_Weight']=10.695
df.loc[df.Item_Identifier == 'FDG04','Item_Weight']=13.1
df.loc[df.Item_Identifier == 'NCF55','Item_Weight']=6.675
df.loc[df.Item_Identifier == 'NCW30','Item_Weight']=5.21
df.loc[df.Item_Identifier == 'NCW05','Item_Weight']=20.25
df.loc[df.Item_Identifier == 'FDS09','Item_Weight']=8.895
df.loc[df.Item_Identifier == 'FDU43','Item_Weight']=19.35
df.loc[df.Item_Identifier == 'FDO49','Item_Weight']=10.6
df.loc[df.Item_Identifier == 'NCT53','Item_Weight']=5.4

#revisaremos si ya no hay valores faltantes, Item_Weight debería estar en 0
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     4
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# Export DataFrame to Excel File
df.to_excel(excel_writer='valoresfaltantes_Item_Weight.xlsx',index=False)
